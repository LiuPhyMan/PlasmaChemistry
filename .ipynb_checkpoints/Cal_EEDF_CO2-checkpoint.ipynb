# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
from matplotlib import pyplot as plt
from plasmistry.electron import EEDF
from plasmistry.electron import get_maxwell_eedf
from plasmistry.molecule import get_ideal_gas_density

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,9)
plt.rcParams["font.size"] = 14

# %%
np.set_printoptions(precision=1, linewidth=130, edgeitems=5)
pd.options.display.float_format = '{:,.1e}'.format

# %% [markdown]
# ### Read inelas reactions

# %%
inelas_df_forward = pd.read_pickle('rctn_dataframe_forward.pkl')
inelas_df_backward = pd.read_pickle('rctn_dataframe_backward.pkl')

# %%
inelas_df_forward.loc[0, 'cross_section']
# Out:
# array([[1.0e-04, 1.0e-04, 1.0e-04, 1.0e-04, 1.0e-04, ..., 9.9e+02, 1.0e+03, 1.0e+03, 1.0e+03, 1.0e+03],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 2.2e-25, 2.2e-25, 2.2e-25, 2.2e-25, 2.2e-25]])

# %%
inelas_df = pd.concat([inelas_df_forward, inelas_df_backward], ignore_index=True)
# inelas_df = pd.read_pickle("rctn_dataframe_H2_dis_via_b.pkl")
inelas_df = pd.read_pickle("CO2_ele_vib_forward_df.pkl")

# %%
inelas_df
# Out:
#                           formula        type  threshold_eV  \
# 0          E + CO2 => E + CO2(v1)  excitation       2.9e-01
# 1          E + CO2 => E + CO2(v2)  excitation       5.8e-01
# 2          E + CO2 => E + CO2(v3)  excitation       8.6e-01
# 3          E + CO2 => E + CO2(v4)  excitation       1.1e+00
# 4          E + CO2 => E + CO2(v5)  excitation       1.4e+00
# 5          E + CO2 => E + CO2(v6)  excitation       1.7e+00
# 6          E + CO2 => E + CO2(v7)  excitation       2.0e+00
# 7          E + CO2 => E + CO2(v8)  excitation       2.2e+00
# 8          E + CO2 => E + CO2(v9)  excitation       2.5e+00
# 9         E + CO2 => E + CO2(v10)  excitation       2.8e+00
# 10        E + CO2 => E + CO2(v11)  excitation       3.0e+00
# 11        E + CO2 => E + CO2(v12)  excitation       3.3e+00
# 12        E + CO2 => E + CO2(v13)  excitation       3.5e+00
# 13        E + CO2 => E + CO2(v14)  excitation       3.8e+00
# 14        E + CO2 => E + CO2(v15)  excitation       4.0e+00
# 15        E + CO2 => E + CO2(v16)  excitation       4.3e+00
# 16        E + CO2 => E + CO2(v17)  excitation       4.5e+00
# 17        E + CO2 => E + CO2(v18)  excitation       4.8e+00
# 18        E + CO2 => E + CO2(v19)  excitation       5.0e+00
# 19        E + CO2 => E + CO2(v20)  excitation       5.2e+00
# 20        E + CO2 => E + CO2(v21)  excitation       5.5e+00
# 21     E + CO2(v1) => E + CO2(v2)  excitation       2.9e-01
# 22     E + CO2(v1) => E + CO2(v3)  excitation       5.7e-01
# 23     E + CO2(v1) => E + CO2(v4)  excitation       8.6e-01
# 24     E + CO2(v1) => E + CO2(v5)  excitation       1.1e+00
# 25     E + CO2(v1) => E + CO2(v6)  excitation       1.4e+00
# 26     E + CO2(v1) => E + CO2(v7)  excitation       1.7e+00
# 27     E + CO2(v1) => E + CO2(v8)  excitation       2.0e+00
# 28     E + CO2(v1) => E + CO2(v9)  excitation       2.2e+00
# 29    E + CO2(v1) => E + CO2(v10)  excitation       2.5e+00
# ..                            ...         ...           ...
# 201  E + CO2(v13) => E + CO2(v20)  excitation       1.7e+00
# 202  E + CO2(v13) => E + CO2(v21)  excitation       1.9e+00
# 203  E + CO2(v14) => E + CO2(v15)  excitation       2.5e-01
# 204  E + CO2(v14) => E + CO2(v16)  excitation       4.9e-01
# 205  E + CO2(v14) => E + CO2(v17)  excitation       7.3e-01
# 206  E + CO2(v14) => E + CO2(v18)  excitation       9.7e-01
# 207  E + CO2(v14) => E + CO2(v19)  excitation       1.2e+00
# 208  E + CO2(v14) => E + CO2(v20)  excitation       1.4e+00
# 209  E + CO2(v14) => E + CO2(v21)  excitation       1.7e+00
# 210  E + CO2(v15) => E + CO2(v16)  excitation       2.4e-01
# 211  E + CO2(v15) => E + CO2(v17)  excitation       4.9e-01
# 212  E + CO2(v15) => E + CO2(v18)  excitation       7.3e-01
# 213  E + CO2(v15) => E + CO2(v19)  excitation       9.6e-01
# 214  E + CO2(v15) => E + CO2(v20)  excitation       1.2e+00
# 215  E + CO2(v15) => E + CO2(v21)  excitation       1.4e+00
# 216  E + CO2(v16) => E + CO2(v17)  excitation       2.4e-01
# 217  E + CO2(v16) => E + CO2(v18)  excitation       4.8e-01
# 218  E + CO2(v16) => E + CO2(v19)  excitation       7.2e-01
# 219  E + CO2(v16) => E + CO2(v20)  excitation       9.5e-01
# 220  E + CO2(v16) => E + CO2(v21)  excitation       1.2e+00
# 221  E + CO2(v17) => E + CO2(v18)  excitation       2.4e-01
# 222  E + CO2(v17) => E + CO2(v19)  excitation       4.7e-01
# 223  E + CO2(v17) => E + CO2(v20)  excitation       7.1e-01
# 224  E + CO2(v17) => E + CO2(v21)  excitation       9.4e-01
# 225  E + CO2(v18) => E + CO2(v19)  excitation       2.4e-01
# 226  E + CO2(v18) => E + CO2(v20)  excitation       4.7e-01
# 227  E + CO2(v18) => E + CO2(v21)  excitation       7.0e-01
# 228  E + CO2(v19) => E + CO2(v20)  excitation       2.3e-01
# 229  E + CO2(v19) => E + CO2(v21)  excitation       4.6e-01
# 230  E + CO2(v20) => E + CO2(v21)  excitation       2.3e-01
#
#                                          cross_section
# 0    [[0.291, 0.3, 0.31, 0.32, 0.33, 0.35, 0.38, 0....
# 1    [[0.57939, 0.58839, 0.59839, 0.60839, 0.61839,...
# 2    [[0.86469, 0.87369, 0.88369, 0.89369, 0.90369,...
# 3    [[1.1469, 1.1559, 1.1659, 1.1759, 1.1859, 1.20...
# 4    [[1.42601, 1.43501, 1.44501, 1.45501, 1.46501,...
# 5    [[1.70203, 1.71103, 1.72103, 1.73103, 1.74103,...
# 6    [[1.97495, 1.98395, 1.99395, 2.00395, 2.01395,...
# 7    [[2.24478, 2.25378, 2.26378, 2.27378, 2.28378,...
# 8    [[2.51151, 2.52051, 2.53051, 2.54051, 2.55051,...
# 9    [[2.77515, 2.78415, 2.79415, 2.80415, 2.81415,...
# 10   [[3.03569, 3.04469, 3.05469, 3.06469, 3.07469,...
# 11   [[3.29314, 3.30214, 3.31214, 3.32214, 3.33214,...
# 12   [[3.54749, 3.55649, 3.56649, 3.57649, 3.58649,...
# 13   [[3.79875, 3.80775, 3.81775, 3.82775, 3.83775,...
# 14   [[4.04692, 4.05592, 4.06592, 4.07592, 4.08592,...
# 15   [[4.29199, 4.30099, 4.31099, 4.32099, 4.33099,...
# 16   [[4.53396, 4.54296, 4.55296, 4.56296, 4.57296,...
# 17   [[4.77284, 4.78184, 4.79184, 4.80184, 4.81184,...
# 18   [[5.00863, 5.01763, 5.02763, 5.03763, 5.04763,...
# 19   [[5.24132, 5.25032, 5.26032, 5.27032, 5.28032,...
# 20   [[5.47092, 5.47992, 5.48992, 5.49992, 5.50992,...
# 21   [[0.28791, 0.29691, 0.30691, 0.31691, 0.32691,...
# 22   [[0.57321, 0.58221, 0.59221, 0.60221, 0.61221,...
# 23   [[0.85541, 0.86441, 0.87441, 0.88441, 0.89441,...
# 24   [[1.13452, 1.14352, 1.15352, 1.16352, 1.17352,...
# 25   [[1.41054, 1.41954, 1.42954, 1.43954, 1.44954,...
# 26   [[1.68346, 1.69246, 1.70246, 1.71246, 1.72246,...
# 27   [[1.95329, 1.96229, 1.97229, 1.98229, 1.99229,...
# 28   [[2.22002, 2.22902, 2.23902, 2.24902, 2.25902,...
# 29   [[2.48366, 2.49266, 2.50266, 2.51266, 2.52266,...
# ..                                                 ...
# 201  [[1.69334, 1.70234, 1.71234, 1.72234, 1.73234,...
# 202  [[1.92294, 1.93194, 1.94194, 1.95194, 1.96194,...
# 203  [[0.24768, 0.25668, 0.26668, 0.27668, 0.28668,...
# 204  [[0.49275, 0.50175, 0.51175, 0.52175, 0.53175,...
# 205  [[0.73472, 0.74372, 0.75372, 0.76372, 0.77372,...
# 206  [[0.9736, 0.9826, 0.9926, 1.0026, 1.0126, 1.03...
# 207  [[1.20939, 1.21839, 1.22839, 1.23839, 1.24839,...
# 208  [[1.44208, 1.45108, 1.46108, 1.47108, 1.48108,...
# 209  [[1.67168, 1.68068, 1.69068, 1.70068, 1.71068,...
# 210  [[0.24458, 0.25358, 0.26358, 0.27358, 0.28358,...
# 211  [[0.48656, 0.49556, 0.50556, 0.51556, 0.52556,...
# 212  [[0.72544, 0.73444, 0.74444, 0.75444, 0.76444,...
# 213  [[0.96122, 0.97022, 0.98022, 0.99022, 1.00022,...
# 214  [[1.19392, 1.20292, 1.21292, 1.22292, 1.23292,...
# 215  [[1.42351, 1.43251, 1.44251, 1.45251, 1.46251,...
# 216  [[0.24149, 0.25049, 0.26049, 0.27049, 0.28049,...
# 217  [[0.48037, 0.48937, 0.49937, 0.50937, 0.51937,...
# 218  [[0.71615, 0.72515, 0.73515, 0.74515, 0.75515,...
# 219  [[0.94885, 0.95785, 0.96785, 0.97785, 0.98785,...
# 220  [[1.17844, 1.18744, 1.19744, 1.20744, 1.21744,...
# 221  [[0.23839, 0.24739, 0.25739, 0.26739, 0.27739,...
# 222  [[0.47418, 0.48318, 0.49318, 0.50318, 0.51318,...
# 223  [[0.70687, 0.71587, 0.72587, 0.73587, 0.74587,...
# 224  [[0.93647, 0.94547, 0.95547, 0.96547, 0.97547,...
# 225  [[0.2353, 0.2443, 0.2543, 0.2643, 0.2743, 0.29...
# 226  [[0.46799, 0.47699, 0.48699, 0.49699, 0.50699,...
# 227  [[0.69759, 0.70659, 0.71659, 0.72659, 0.73659,...
# 228  [[0.2322, 0.2412, 0.2512, 0.2612, 0.2712, 0.29...
# 229  [[0.4618, 0.4708, 0.4808, 0.4908, 0.5008, 0.52...
# 230  [[0.22911, 0.23811, 0.24811, 0.25811, 0.26811,...
#
# [231 rows x 4 columns]

# %%
inelas_df.loc[0, 'cross_section']
# Out:
# array([[2.9e-01, 3.0e-01, 3.1e-01, 3.2e-01, 3.3e-01, 3.5e-01, 3.8e-01, 4.0e-01, 4.5e-01, 5.0e-01, 6.0e-01, 8.0e-01, 1.0e+00,
#         1.5e+00, 2.0e+00, 3.0e+00, 4.5e+00, 6.0e+00, 8.0e+00, 1.0e+01, 2.5e+01, 3.0e+01, 1.0e+02],
#        [0.0e+00, 9.5e-21, 1.7e-20, 1.9e-20, 2.0e-20, 2.2e-20, 2.2e-20, 2.2e-20, 2.0e-20, 1.9e-20, 1.5e-20, 1.2e-20, 1.0e-20,
#         7.6e-21, 6.4e-21, 4.9e-21, 4.4e-21, 4.1e-21, 4.8e-21, 2.6e-21, 1.4e-21, 1.0e-21, 0.0e+00]])

# %% [markdown]
# ### Choose the reactions considered.

# %%
#inelas_df = inelas_df.iloc[[0,1,2,3,4,5,6,7,8]].reset_index(drop=True)
inelas_df
# Out:
#                           formula        type  threshold_eV  \
# 0          E + CO2 => E + CO2(v1)  excitation       2.9e-01
# 1          E + CO2 => E + CO2(v2)  excitation       5.8e-01
# 2          E + CO2 => E + CO2(v3)  excitation       8.6e-01
# 3          E + CO2 => E + CO2(v4)  excitation       1.1e+00
# 4          E + CO2 => E + CO2(v5)  excitation       1.4e+00
# 5          E + CO2 => E + CO2(v6)  excitation       1.7e+00
# 6          E + CO2 => E + CO2(v7)  excitation       2.0e+00
# 7          E + CO2 => E + CO2(v8)  excitation       2.2e+00
# 8          E + CO2 => E + CO2(v9)  excitation       2.5e+00
# 9         E + CO2 => E + CO2(v10)  excitation       2.8e+00
# 10        E + CO2 => E + CO2(v11)  excitation       3.0e+00
# 11        E + CO2 => E + CO2(v12)  excitation       3.3e+00
# 12        E + CO2 => E + CO2(v13)  excitation       3.5e+00
# 13        E + CO2 => E + CO2(v14)  excitation       3.8e+00
# 14        E + CO2 => E + CO2(v15)  excitation       4.0e+00
# 15        E + CO2 => E + CO2(v16)  excitation       4.3e+00
# 16        E + CO2 => E + CO2(v17)  excitation       4.5e+00
# 17        E + CO2 => E + CO2(v18)  excitation       4.8e+00
# 18        E + CO2 => E + CO2(v19)  excitation       5.0e+00
# 19        E + CO2 => E + CO2(v20)  excitation       5.2e+00
# 20        E + CO2 => E + CO2(v21)  excitation       5.5e+00
# 21     E + CO2(v1) => E + CO2(v2)  excitation       2.9e-01
# 22     E + CO2(v1) => E + CO2(v3)  excitation       5.7e-01
# 23     E + CO2(v1) => E + CO2(v4)  excitation       8.6e-01
# 24     E + CO2(v1) => E + CO2(v5)  excitation       1.1e+00
# 25     E + CO2(v1) => E + CO2(v6)  excitation       1.4e+00
# 26     E + CO2(v1) => E + CO2(v7)  excitation       1.7e+00
# 27     E + CO2(v1) => E + CO2(v8)  excitation       2.0e+00
# 28     E + CO2(v1) => E + CO2(v9)  excitation       2.2e+00
# 29    E + CO2(v1) => E + CO2(v10)  excitation       2.5e+00
# ..                            ...         ...           ...
# 201  E + CO2(v13) => E + CO2(v20)  excitation       1.7e+00
# 202  E + CO2(v13) => E + CO2(v21)  excitation       1.9e+00
# 203  E + CO2(v14) => E + CO2(v15)  excitation       2.5e-01
# 204  E + CO2(v14) => E + CO2(v16)  excitation       4.9e-01
# 205  E + CO2(v14) => E + CO2(v17)  excitation       7.3e-01
# 206  E + CO2(v14) => E + CO2(v18)  excitation       9.7e-01
# 207  E + CO2(v14) => E + CO2(v19)  excitation       1.2e+00
# 208  E + CO2(v14) => E + CO2(v20)  excitation       1.4e+00
# 209  E + CO2(v14) => E + CO2(v21)  excitation       1.7e+00
# 210  E + CO2(v15) => E + CO2(v16)  excitation       2.4e-01
# 211  E + CO2(v15) => E + CO2(v17)  excitation       4.9e-01
# 212  E + CO2(v15) => E + CO2(v18)  excitation       7.3e-01
# 213  E + CO2(v15) => E + CO2(v19)  excitation       9.6e-01
# 214  E + CO2(v15) => E + CO2(v20)  excitation       1.2e+00
# 215  E + CO2(v15) => E + CO2(v21)  excitation       1.4e+00
# 216  E + CO2(v16) => E + CO2(v17)  excitation       2.4e-01
# 217  E + CO2(v16) => E + CO2(v18)  excitation       4.8e-01
# 218  E + CO2(v16) => E + CO2(v19)  excitation       7.2e-01
# 219  E + CO2(v16) => E + CO2(v20)  excitation       9.5e-01
# 220  E + CO2(v16) => E + CO2(v21)  excitation       1.2e+00
# 221  E + CO2(v17) => E + CO2(v18)  excitation       2.4e-01
# 222  E + CO2(v17) => E + CO2(v19)  excitation       4.7e-01
# 223  E + CO2(v17) => E + CO2(v20)  excitation       7.1e-01
# 224  E + CO2(v17) => E + CO2(v21)  excitation       9.4e-01
# 225  E + CO2(v18) => E + CO2(v19)  excitation       2.4e-01
# 226  E + CO2(v18) => E + CO2(v20)  excitation       4.7e-01
# 227  E + CO2(v18) => E + CO2(v21)  excitation       7.0e-01
# 228  E + CO2(v19) => E + CO2(v20)  excitation       2.3e-01
# 229  E + CO2(v19) => E + CO2(v21)  excitation       4.6e-01
# 230  E + CO2(v20) => E + CO2(v21)  excitation       2.3e-01
#
#                                          cross_section
# 0    [[0.291, 0.3, 0.31, 0.32, 0.33, 0.35, 0.38, 0....
# 1    [[0.57939, 0.58839, 0.59839, 0.60839, 0.61839,...
# 2    [[0.86469, 0.87369, 0.88369, 0.89369, 0.90369,...
# 3    [[1.1469, 1.1559, 1.1659, 1.1759, 1.1859, 1.20...
# 4    [[1.42601, 1.43501, 1.44501, 1.45501, 1.46501,...
# 5    [[1.70203, 1.71103, 1.72103, 1.73103, 1.74103,...
# 6    [[1.97495, 1.98395, 1.99395, 2.00395, 2.01395,...
# 7    [[2.24478, 2.25378, 2.26378, 2.27378, 2.28378,...
# 8    [[2.51151, 2.52051, 2.53051, 2.54051, 2.55051,...
# 9    [[2.77515, 2.78415, 2.79415, 2.80415, 2.81415,...
# 10   [[3.03569, 3.04469, 3.05469, 3.06469, 3.07469,...
# 11   [[3.29314, 3.30214, 3.31214, 3.32214, 3.33214,...
# 12   [[3.54749, 3.55649, 3.56649, 3.57649, 3.58649,...
# 13   [[3.79875, 3.80775, 3.81775, 3.82775, 3.83775,...
# 14   [[4.04692, 4.05592, 4.06592, 4.07592, 4.08592,...
# 15   [[4.29199, 4.30099, 4.31099, 4.32099, 4.33099,...
# 16   [[4.53396, 4.54296, 4.55296, 4.56296, 4.57296,...
# 17   [[4.77284, 4.78184, 4.79184, 4.80184, 4.81184,...
# 18   [[5.00863, 5.01763, 5.02763, 5.03763, 5.04763,...
# 19   [[5.24132, 5.25032, 5.26032, 5.27032, 5.28032,...
# 20   [[5.47092, 5.47992, 5.48992, 5.49992, 5.50992,...
# 21   [[0.28791, 0.29691, 0.30691, 0.31691, 0.32691,...
# 22   [[0.57321, 0.58221, 0.59221, 0.60221, 0.61221,...
# 23   [[0.85541, 0.86441, 0.87441, 0.88441, 0.89441,...
# 24   [[1.13452, 1.14352, 1.15352, 1.16352, 1.17352,...
# 25   [[1.41054, 1.41954, 1.42954, 1.43954, 1.44954,...
# 26   [[1.68346, 1.69246, 1.70246, 1.71246, 1.72246,...
# 27   [[1.95329, 1.96229, 1.97229, 1.98229, 1.99229,...
# 28   [[2.22002, 2.22902, 2.23902, 2.24902, 2.25902,...
# 29   [[2.48366, 2.49266, 2.50266, 2.51266, 2.52266,...
# ..                                                 ...
# 201  [[1.69334, 1.70234, 1.71234, 1.72234, 1.73234,...
# 202  [[1.92294, 1.93194, 1.94194, 1.95194, 1.96194,...
# 203  [[0.24768, 0.25668, 0.26668, 0.27668, 0.28668,...
# 204  [[0.49275, 0.50175, 0.51175, 0.52175, 0.53175,...
# 205  [[0.73472, 0.74372, 0.75372, 0.76372, 0.77372,...
# 206  [[0.9736, 0.9826, 0.9926, 1.0026, 1.0126, 1.03...
# 207  [[1.20939, 1.21839, 1.22839, 1.23839, 1.24839,...
# 208  [[1.44208, 1.45108, 1.46108, 1.47108, 1.48108,...
# 209  [[1.67168, 1.68068, 1.69068, 1.70068, 1.71068,...
# 210  [[0.24458, 0.25358, 0.26358, 0.27358, 0.28358,...
# 211  [[0.48656, 0.49556, 0.50556, 0.51556, 0.52556,...
# 212  [[0.72544, 0.73444, 0.74444, 0.75444, 0.76444,...
# 213  [[0.96122, 0.97022, 0.98022, 0.99022, 1.00022,...
# 214  [[1.19392, 1.20292, 1.21292, 1.22292, 1.23292,...
# 215  [[1.42351, 1.43251, 1.44251, 1.45251, 1.46251,...
# 216  [[0.24149, 0.25049, 0.26049, 0.27049, 0.28049,...
# 217  [[0.48037, 0.48937, 0.49937, 0.50937, 0.51937,...
# 218  [[0.71615, 0.72515, 0.73515, 0.74515, 0.75515,...
# 219  [[0.94885, 0.95785, 0.96785, 0.97785, 0.98785,...
# 220  [[1.17844, 1.18744, 1.19744, 1.20744, 1.21744,...
# 221  [[0.23839, 0.24739, 0.25739, 0.26739, 0.27739,...
# 222  [[0.47418, 0.48318, 0.49318, 0.50318, 0.51318,...
# 223  [[0.70687, 0.71587, 0.72587, 0.73587, 0.74587,...
# 224  [[0.93647, 0.94547, 0.95547, 0.96547, 0.97547,...
# 225  [[0.2353, 0.2443, 0.2543, 0.2643, 0.2743, 0.29...
# 226  [[0.46799, 0.47699, 0.48699, 0.49699, 0.50699,...
# 227  [[0.69759, 0.70659, 0.71659, 0.72659, 0.73659,...
# 228  [[0.2322, 0.2412, 0.2512, 0.2612, 0.2712, 0.29...
# 229  [[0.4618, 0.4708, 0.4808, 0.4908, 0.5008, 0.52...
# 230  [[0.22911, 0.23811, 0.24811, 0.25811, 0.26811,...
#
# [231 rows x 4 columns]

# %%
inelas_df.loc[0, 'cross_section']
# Out:
# array([[2.9e-01, 3.0e-01, 3.1e-01, 3.2e-01, 3.3e-01, 3.5e-01, 3.8e-01, 4.0e-01, 4.5e-01, 5.0e-01, 6.0e-01, 8.0e-01, 1.0e+00,
#         1.5e+00, 2.0e+00, 3.0e+00, 4.5e+00, 6.0e+00, 8.0e+00, 1.0e+01, 2.5e+01, 3.0e+01, 1.0e+02],
#        [0.0e+00, 9.5e-21, 1.7e-20, 1.9e-20, 2.0e-20, 2.2e-20, 2.2e-20, 2.2e-20, 2.0e-20, 1.9e-20, 1.5e-20, 1.2e-20, 1.0e-20,
#         7.6e-21, 6.4e-21, 4.9e-21, 4.4e-21, 4.1e-21, 4.8e-21, 2.6e-21, 1.4e-21, 1.0e-21, 0.0e+00]])

# %%
eedf = EEDF(max_energy_eV=50, grid_number=500)

# %%
# eedf.initialize(rctn_with_crostn_df=inelas_df, total_species=['E', 'H2'] + [f'H2(v{v})' for v in range(1, 15)])
# eedf.initialize(rctn_with_crostn_df=inelas_df, total_species=['E', 'H2', 'H2(v1)', 'H2(v2)', 'H2(v3)'])
eedf.initialize(rctn_with_crostn_df=inelas_df, total_species=['E', 'CO2'] + [f'CO2(v{v})' for v in range(1, 22)])

# %%
eedf.rate_const_matrix_e_inelas_electron.toarray()
# Out:
# array([[ 0.0e+00,  0.0e+00,  0.0e+00,  6.9e-15,  0.0e+00, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  6.6e-16,  7.3e-15, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  7.0e-16, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00, -7.5e-15,  0.0e+00, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, -8.0e-15, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00],
#        ...,
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, ..., -7.7e-15,  0.0e+00,  1.1e-15,  1.9e-15,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, ...,  0.0e+00, -7.7e-15,  0.0e+00,  1.1e-15,  1.9e-15],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, ...,  0.0e+00,  0.0e+00, -7.7e-15,  0.0e+00,  1.1e-15],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, ...,  0.0e+00,  0.0e+00,  0.0e+00, -7.7e-15,  0.0e+00],
#        [ 0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, ...,  0.0e+00,  0.0e+00,  0.0e+00,  0.0e+00, -7.7e-15]])

# %%
eedf.rate_const_matrix_e_inelas_electron.shape
# Out:
# (10500, 500)

# %%
eedf.rate_const_matrix_e_inelas_molecule.shape
# Out:
# (231, 500)

# %%
plt.matshow(eedf.rate_const_matrix_e_inelas_molecule)

# %%
eedf.n_bg_molecule_elas
# Out:
# 1

# %%
eedf.bg_molecule_elas
# Out:
# ['CO2']

# %%
eedf.n_bg_molecule_inelas
# Out:
# 21

# %%
eedf.bg_molecule_inelas
# Out:
# array(['CO2', 'CO2(v1)', 'CO2(v10)', 'CO2(v11)', 'CO2(v12)', 'CO2(v13)', 'CO2(v14)', 'CO2(v15)', 'CO2(v16)', 'CO2(v17)',
#        'CO2(v18)', 'CO2(v19)', 'CO2(v2)', 'CO2(v20)', 'CO2(v3)', 'CO2(v4)', 'CO2(v5)', 'CO2(v6)', 'CO2(v7)', 'CO2(v8)',
#        'CO2(v9)'], dtype=object)

# %%
eedf.n_inelas_rctn
# Out:
# 231

# %%
eedf.bg_molecule_inelas_in_order
# Out:
# array(['CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2', 'CO2',
#        'CO2', 'CO2', 'CO2', 'CO2', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)',
#        'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)', 'CO2(v1)',
#        'CO2(v1)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)',
#        'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v2)', 'CO2(v3)', 'CO2(v3)',
#        'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)',
#        'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v3)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)',
#        'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)', 'CO2(v4)',
#        'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)',
#        'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v5)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)',
#        'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v6)', 'CO2(v7)', 'CO2(v7)',
#        'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)', 'CO2(v7)',
#        'CO2(v7)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v8)',
#        'CO2(v8)', 'CO2(v8)', 'CO2(v8)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)',
#        'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v9)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)',
#        'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v10)', 'CO2(v11)', 'CO2(v11)', 'CO2(v11)', 'CO2(v11)', 'CO2(v11)',
#        'CO2(v11)', 'CO2(v11)', 'CO2(v11)', 'CO2(v11)', 'CO2(v11)', 'CO2(v12)', 'CO2(v12)', 'CO2(v12)', 'CO2(v12)', 'CO2(v12)',
#        'CO2(v12)', 'CO2(v12)', 'CO2(v12)', 'CO2(v12)', 'CO2(v13)', 'CO2(v13)', 'CO2(v13)', 'CO2(v13)', 'CO2(v13)', 'CO2(v13)',
#        'CO2(v13)', 'CO2(v13)', 'CO2(v14)', 'CO2(v14)', 'CO2(v14)', 'CO2(v14)', 'CO2(v14)', 'CO2(v14)', 'CO2(v14)', 'CO2(v15)',
#        'CO2(v15)', 'CO2(v15)', 'CO2(v15)', 'CO2(v15)', 'CO2(v15)', 'CO2(v16)', 'CO2(v16)', 'CO2(v16)', 'CO2(v16)', 'CO2(v16)',
#        'CO2(v17)', 'CO2(v17)', 'CO2(v17)', 'CO2(v17)', 'CO2(v18)', 'CO2(v18)', 'CO2(v18)', 'CO2(v19)', 'CO2(v19)', 'CO2(v20)'],
#       dtype=object)

# %%
plt.spy(eedf.rate_const_matrix_e_inelas_electron, markersize=2)

# %%
eedf.rate_const_matrix_e_inelas_molecule
# Out:
# array([[0.0e+00, 0.0e+00, 1.4e-36, 1.2e-34, 1.3e-34, ..., 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 1.8e-35, 1.8e-35, 1.8e-35, 1.8e-35, 1.8e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 1.1e-35, 1.1e-35, 1.1e-35, 1.1e-35, 1.1e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 6.7e-36, 6.7e-36, 6.7e-36, 6.7e-36, 6.6e-36],
#        ...,
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 1.6e-35, ..., 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, ..., 1.8e-35, 1.8e-35, 1.8e-35, 1.8e-35, 1.8e-35],
#        [0.0e+00, 0.0e+00, 5.3e-35, 1.2e-34, 1.2e-34, ..., 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35],
#        [0.0e+00, 0.0e+00, 0.0e+00, 0.0e+00, 2.2e-35, ..., 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35, 2.9e-35],
#        [0.0e+00, 0.0e+00, 5.7e-35, 1.2e-34, 1.2e-34, ..., 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35, 4.8e-35]])

# %%
N = get_ideal_gas_density(p_Pa=1e5, Tgas_K=1000)
N
# Out:
# 7.242973087680333e+24

# %% [markdown]
# ### Set parameters

# %%
eedf.set_parameters(E=1e6, Tgas=1000, N=N)

# %%
total_species_density = np.ones(23) * N
# total_species_density = np.array([0,1,0,0,0])*N
def dndt_all(t, y):
    eedf.set_density_per_J(y)
    eedf.set_flux(total_species_density=total_species_density)
    return eedf.get_deriv_total(total_species_density=total_species_density)

# %%
y0 = get_maxwell_eedf(eedf.energy_point, Te_eV=0.7)*1e17
time_span = [0, 1e3]
sol = solve_ivp(dndt_all, time_span, y0, method="BDF", rtol=5e-2)

# %%
sol.t
# Out:
# array([0.0e+00, 6.8e-16, 1.4e-15, 8.2e-15, 1.5e-14, 7.0e-14, 1.2e-13, 2.5e-13, 3.7e-13, 4.9e-13, 7.1e-13, 9.2e-13, 1.1e-12,
#        1.4e-12, 1.7e-12, 2.0e-12, 2.3e-12, 2.6e-12, 3.0e-12, 3.4e-12, 3.8e-12, 4.2e-12, 4.7e-12, 5.3e-12, 5.8e-12, 6.4e-12,
#        7.1e-12, 7.9e-12, 8.7e-12, 9.4e-12, 1.1e-11, 1.2e-11, 1.3e-11, 1.4e-11, 1.5e-11, 1.7e-11, 1.9e-11, 2.1e-11, 2.3e-11,
#        2.6e-11, 3.1e-11, 3.6e-11, 4.1e-11, 4.5e-11, 5.6e-11, 6.6e-11, 7.7e-11, 1.0e-10, 1.3e-10, 1.5e-10, 1.7e-10, 2.4e-10,
#        3.1e-10, 3.8e-10, 9.0e-10, 1.4e-09, 6.6e-09, 1.2e-08, 6.3e-08, 1.1e-07, 6.3e-07, 6.5e-07, 6.5e-07, 6.6e-07, 6.7e-07,
#        6.8e-07, 7.8e-07, 8.3e-07, 8.8e-07, 1.4e-06, 1.5e-06, 1.6e-06, 2.9e-06, 4.2e-06, 1.7e-05, 2.0e-05, 2.3e-05, 3.9e-05,
#        5.4e-05, 2.1e-04, 3.7e-04, 1.9e-03, 3.5e-03, 1.1e-02, 1.9e-02, 9.8e-02, 1.1e-01, 1.2e-01, 2.2e-01, 2.6e-01, 3.1e-01,
#        3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01, 3.8e-01,
#        3.9e-01, 4.1e-01, 4.1e-01, 4.2e-01, 4.2e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01,
#        4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01,
#        4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01, 4.3e-01,
#        4.3e-01, 4.4e-01, 4.4e-01, 4.4e-01, 4.4e-01, 4.4e-01, 4.5e-01, 4.7e-01, 5.3e-01, 6.0e-01, 1.2e+00, 1.9e+00, 8.4e+00,
#        1.5e+01, 8.0e+01, 1.4e+02, 8.0e+02, 1.0e+03])

# %%
len(sol.t)
# Out:
# 161

# %%
plt.semilogy(eedf.energy_point_eV, (sol.y.transpose()/np.sqrt(eedf.energy_point)).transpose()[:,::50])
# Out:
# [<matplotlib.lines.Line2D at 0x1de5c477d68>,
#  <matplotlib.lines.Line2D at 0x1de5ca795f8>,
#  <matplotlib.lines.Line2D at 0x1de5ca79748>,
#  <matplotlib.lines.Line2D at 0x1de5ca79898>]

# %%
eedf.set_density_per_J(sol.y[:,0])
eedf.plot_normalized_eepf()

# %%
eedf.plot_normalized_eedf()

# %%
eedf.set_density_per_J(sol.y[:,-1])
eedf.plot_normalized_eepf(xlim=(0,12), ylim=(1e-12, 1e1))

# %%
print(eedf)
# Out:
#
#  ===============
#
#                ENERGY SPACE (eV) : (0.0, 50.0)
#
#      NUMBER OF DISCRETIZED CELLS : 500 cells
#
#             ENERGY INTERVAL (eV) : 0.100
#
#  ===============
#
#             ELECTRON TEMPERATURE : 0.4326 eV
#
#             ELECTRON MEAN ENERGY : 0.6488 eV
#
#                 ELECTRON DENSITY : 9.29e+16 m^-3
#
#  ===============
#
#               ELECTRIC FIELD (E) : 1000000 V/m (10.00 kV/cm)
#
#           GAS TEMPERATURE (Tgas) : 1000 K
#
#  BACKGROUND MOLECULE DENSITY (N) : 7.2e+24 m^-3
#
#     REDUCED ELECTRIC FIELD (E/N) : 138.1 Td
#
#  ===============
#
#      ELASTIC COLLISION MOLECULES : ['CO2']
#
#    INELASTIC COLLISION MOLECULES : ['CO2' 'CO2(v1)' 'CO2(v10)' 'CO2(v11)' 'CO2(v12)' 'CO2(v13)' 'CO2(v14)' 'CO2(v15)' 'CO2(v16)' 'CO2(v17)' 'CO2(v18)' 'CO2(v19)'
#  'CO2(v2)' 'CO2(v20)' 'CO2(v3)' 'CO2(v4)' 'CO2(v5)' 'CO2(v6)' 'CO2(v7)' 'CO2(v8)' 'CO2(v9)']

# %%
eedf._get_molecule_rate_const_e_inelas()
# Out:
# array([3.7e-15, 1.6e-15, 7.3e-16, 3.5e-16, 1.7e-16, 8.5e-17, 4.1e-17, 2.0e-17, 9.5e-18, 4.4e-18, 2.0e-18, 9.2e-19, 4.1e-19,
#        1.8e-19, 8.3e-20, 3.8e-20, 1.8e-20, 8.3e-21, 4.0e-21, 1.9e-21, 9.3e-22, 3.7e-15, 1.6e-15, 7.3e-16, 3.6e-16, 1.8e-16,
#        8.5e-17, 4.2e-17, 2.0e-17, 9.7e-18, 4.6e-18, 2.1e-18, 9.6e-19, 4.3e-19, 1.9e-19, 8.8e-20, 4.0e-20, 1.8e-20, 8.9e-21,
#        4.2e-21, 2.0e-21, 3.7e-15, 1.6e-15, 7.4e-16, 3.6e-16, 1.8e-16, 8.7e-17, 4.3e-17, 2.1e-17, 1.0e-17, 4.8e-18, 2.2e-18,
#        1.0e-18, 4.5e-19, 2.0e-19, 9.2e-20, 4.2e-20, 2.0e-20, 9.3e-21, 4.4e-21, 3.7e-15, 1.6e-15, 7.5e-16, 3.6e-16, 1.8e-16,
#        8.8e-17, 4.4e-17, 2.1e-17, 1.0e-17, 4.8e-18, 2.3e-18, 1.0e-18, 4.8e-19, 2.1e-19, 9.8e-20, 4.5e-20, 2.1e-20, 1.0e-20,
#        3.7e-15, 1.6e-15, 7.5e-16, 3.7e-16, 1.8e-16, 9.0e-17, 4.4e-17, 2.2e-17, 1.1e-17, 5.0e-18, 2.4e-18, 1.1e-18, 4.9e-19,
#        2.3e-19, 1.0e-19, 4.7e-20, 2.2e-20, 3.7e-15, 1.6e-15, 7.6e-16, 3.7e-16, 1.8e-16, 9.1e-17, 4.5e-17, 2.2e-17, 1.1e-17,
#        5.2e-18, 2.4e-18, 1.1e-18, 5.2e-19, 2.4e-19, 1.1e-19, 5.0e-20, 3.7e-15, 1.6e-15, 7.7e-16, 3.7e-16, 1.8e-16, 9.2e-17,
#        4.6e-17, 2.3e-17, 1.1e-17, 5.3e-18, 2.5e-18, 1.2e-18, 5.5e-19, 2.5e-19, 1.1e-19, 3.7e-15, 1.6e-15, 7.8e-16, 3.8e-16,
#        1.9e-16, 9.3e-17, 4.7e-17, 2.3e-17, 1.1e-17, 5.5e-18, 2.6e-18, 1.2e-18, 5.7e-19, 2.6e-19, 3.8e-15, 1.6e-15, 7.8e-16,
#        3.8e-16, 1.9e-16, 9.5e-17, 4.8e-17, 2.3e-17, 1.2e-17, 5.7e-18, 2.7e-18, 1.3e-18, 6.1e-19, 3.8e-15, 1.7e-15, 7.8e-16,
#        3.8e-16, 1.9e-16, 9.6e-17, 4.8e-17, 2.4e-17, 1.2e-17, 5.8e-18, 2.8e-18, 1.4e-18, 3.8e-15, 1.7e-15, 7.9e-16, 3.9e-16,
#        1.9e-16, 9.8e-17, 4.9e-17, 2.5e-17, 1.2e-17, 6.0e-18, 2.9e-18, 3.8e-15, 1.7e-15, 8.0e-16, 3.9e-16, 2.0e-16, 9.9e-17,
#        5.0e-17, 2.5e-17, 1.3e-17, 6.2e-18, 3.8e-15, 1.7e-15, 8.0e-16, 4.0e-16, 2.0e-16, 1.0e-16, 5.1e-17, 2.5e-17, 1.3e-17,
#        3.8e-15, 1.7e-15, 8.1e-16, 4.0e-16, 2.0e-16, 1.0e-16, 5.2e-17, 2.6e-17, 3.8e-15, 1.7e-15, 8.2e-16, 4.0e-16, 2.0e-16,
#        1.0e-16, 5.2e-17, 3.9e-15, 1.7e-15, 8.2e-16, 4.1e-16, 2.1e-16, 1.0e-16, 3.9e-15, 1.7e-15, 8.3e-16, 4.1e-16, 2.1e-16,
#        3.9e-15, 1.7e-15, 8.4e-16, 4.2e-16, 3.9e-15, 1.8e-15, 8.5e-16, 3.9e-15, 1.8e-15, 4.0e-15])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(range(eedf.n_inelas_rctn),
        width=eedf._get_molecule_rate_const_e_inelas(),
        height=0.6, log=True)
ax.set_yticks(range(eedf.n_inelas_rctn))
ax.set_yticklabels(eedf.inelas_reaction_dataframe['formula'])
# Out:
# [Text(0, 0, 'E + CO2 => E + CO2(v1)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v2)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v3)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v4)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v5)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2 => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v2)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v3)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v4)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v5)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v1) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v3)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v4)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v5)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v2) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v4)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v5)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v3) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v5)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v4) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v6)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v5) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v7)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v6) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v8)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v7) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v9)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v8) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v10)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v9) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v11)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v10) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v12)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v11) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v13)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v12) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v14)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v13) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v15)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v14) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v16)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v15) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v16) => E + CO2(v17)'),
#  Text(0, 0, 'E + CO2(v16) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v16) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v16) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v16) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v17) => E + CO2(v18)'),
#  Text(0, 0, 'E + CO2(v17) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v17) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v17) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v18) => E + CO2(v19)'),
#  Text(0, 0, 'E + CO2(v18) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v18) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v19) => E + CO2(v20)'),
#  Text(0, 0, 'E + CO2(v19) => E + CO2(v21)'),
#  Text(0, 0, 'E + CO2(v20) => E + CO2(v21)')]

# %%
eedf.plot_normalized_eedf()

# %%
Te_seq = []
ne_seq = []
for _array in sol.y.transpose():
    eedf.set_density_per_J(_array)
    Te_seq.append(eedf.electron_temperature_in_eV)
    ne_seq.append(eedf.electron_density)
plt.semilogx(sol.t, Te_seq, marker='.')
plt.title("Te vs. t")
# Out:
# Text(0.5, 1.0, 'Te vs. t')

# %%
plt.semilogx(sol.t, ne_seq, marker='.')
plt.title("ne vs. t")
# Out:
# Text(0.5, 1.0, 'ne vs. t')

# %%
sol.y
# Out:
# array([[2.5e+35, 2.5e+35, 2.5e+35, 2.6e+35, 2.6e+35, ..., 1.1e+36, 1.1e+36, 1.1e+36, 1.1e+36, 1.1e+36],
#        [3.8e+35, 3.8e+35, 3.8e+35, 3.8e+35, 3.9e+35, ..., 1.1e+36, 1.1e+36, 1.1e+36, 1.0e+36, 1.0e+36],
#        [4.2e+35, 4.2e+35, 4.2e+35, 4.3e+35, 4.3e+35, ..., 8.1e+35, 8.1e+35, 8.1e+35, 7.9e+35, 7.9e+35],
#        [4.3e+35, 4.3e+35, 4.3e+35, 4.3e+35, 4.3e+35, ..., 5.8e+35, 5.8e+35, 5.8e+35, 5.7e+35, 5.6e+35],
#        [4.2e+35, 4.2e+35, 4.2e+35, 4.2e+35, 4.2e+35, ..., 4.3e+35, 4.3e+35, 4.3e+35, 4.2e+35, 4.1e+35],
#        ...,
#        [1.5e+06, 1.5e+06, 1.5e+06, 1.6e+06, 1.7e+06, ..., 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24],
#        [1.3e+06, 1.3e+06, 1.3e+06, 1.4e+06, 1.5e+06, ..., 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24],
#        [1.2e+06, 1.2e+06, 1.2e+06, 1.3e+06, 1.4e+06, ..., 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24],
#        [1.0e+06, 1.0e+06, 1.0e+06, 1.1e+06, 1.3e+06, ..., 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24],
#        [8.7e+05, 9.0e+05, 9.2e+05, 1.1e+06, 1.2e+06, ..., 1.1e+24, 1.1e+24, 1.1e+24, 1.1e+24, 1.0e+24]])

# %%
eedf.set_density_per_J(sol.y[:,-1])
eedf.set_flux(total_species_density=total_species_density)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(eedf.energy_point_eV, eedf._get_deriv_ef(), 
        linewidth=0.4, marker='.', label='ef')
ax.plot(eedf.energy_point_eV, eedf._get_deriv_el(), 
        linewidth=0.4, marker='.', label='el')
ax.plot(eedf.energy_point_eV, eedf._get_deriv_ee(), 
        linewidth=0.4, marker='.', label='ee')
ax.plot(eedf.energy_point_eV, eedf._get_electron_rate_e_inelas(density=total_species_density), 
        linewidth=0.4, marker='.', label='e_inelas')
ax.plot(eedf.energy_point_eV, eedf.get_deriv_total(total_species_density=total_species_density), 
        linewidth=1.5, marker='.', label='sum')
# ax.plot(eedf.energy_nodes,eedf.J_flux_el, marker='.', label='el')
# ax.plot(eedf.energy_nodes,eedf.J_flux_ee, marker='.', label='ee')
# ax.plot(eedf.energy_nodes,eedf.J_flux_ef+eedf.J_flux_el+eedf.J_flux_ee, marker='.', label='ef+el+ee')
# ax.set_yscale('symlog')
# ax.set_xscale('log')
ax.set_xlim((0,2))
ax.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(eedf.energy_point_eV, eedf._get_deriv_ef()*eedf.energy_point, 
        linewidth=0.4, marker='.', label='ef')
ax.plot(eedf.energy_point_eV, eedf._get_deriv_el()*eedf.energy_point, 
        linewidth=0.4, marker='.', label='el')
ax.plot(eedf.energy_point_eV, eedf._get_deriv_ee()*eedf.energy_point, 
        linewidth=0.4, marker='.', label='ee')
ax.plot(eedf.energy_point_eV, eedf._get_electron_rate_e_inelas(density=total_species_density)*eedf.energy_point, 
        linewidth=0.4, marker='.', label='e_inelas')
ax.plot(eedf.energy_point_eV, eedf.get_deriv_total(total_species_density=total_species_density)*eedf.energy_point, 
        linewidth=1.5, marker='.', label='sum')
# ax.plot(eedf.energy_nodes,eedf.J_flux_el, marker='.', label='el')
# ax.plot(eedf.energy_nodes,eedf.J_flux_ee, marker='.', label='ee')
# ax.plot(eedf.energy_nodes,eedf.J_flux_ef+eedf.J_flux_el+eedf.J_flux_ee, marker='.', label='ef+el+ee')
# ax.set_yscale('symlog')
# ax.set_xscale('log')
ax.set_xlim((0,2))
ax.legend()

# %%
energy_gain_ef = (eedf._get_deriv_ef()*eedf.energy_point).sum()
energy_lose_el = (eedf._get_deriv_el()*eedf.energy_point).sum()
energy_gain_ee = (eedf._get_deriv_ee()*eedf.energy_point).sum()
energy_gain_e_inelas = (eedf._get_electron_rate_e_inelas(density=total_species_density)*eedf.energy_point).sum()
energy_gain_net = (eedf.get_deriv_total(total_species_density=total_species_density)*eedf.energy_point).sum()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.barh(range(5),
        width=[energy_gain_ef, energy_lose_el, energy_gain_ee, energy_gain_e_inelas, energy_gain_net],
       height=0.6)
ax.set_yticks(range(5))
ax.set_yticklabels(['ef', 'el', 'ee', 'inelas', 'net'])
ax.set_title("energy lose")
# Out:
# Text(0.5, 1.0, 'energy lose')

# %%
eedf.inelas_rctn_info
# Out:
#                           formula        type  threshold_eV  rate const  \
# 0          E + CO2 => E + CO2(v1)  excitation       2.9e-01     3.7e-15
# 1          E + CO2 => E + CO2(v2)  excitation       5.8e-01     1.6e-15
# 2          E + CO2 => E + CO2(v3)  excitation       8.6e-01     7.3e-16
# 3          E + CO2 => E + CO2(v4)  excitation       1.1e+00     3.5e-16
# 4          E + CO2 => E + CO2(v5)  excitation       1.4e+00     1.7e-16
# 5          E + CO2 => E + CO2(v6)  excitation       1.7e+00     8.5e-17
# 6          E + CO2 => E + CO2(v7)  excitation       2.0e+00     4.1e-17
# 7          E + CO2 => E + CO2(v8)  excitation       2.2e+00     2.0e-17
# 8          E + CO2 => E + CO2(v9)  excitation       2.5e+00     9.5e-18
# 9         E + CO2 => E + CO2(v10)  excitation       2.8e+00     4.4e-18
# 10        E + CO2 => E + CO2(v11)  excitation       3.0e+00     2.0e-18
# 11        E + CO2 => E + CO2(v12)  excitation       3.3e+00     9.2e-19
# 12        E + CO2 => E + CO2(v13)  excitation       3.5e+00     4.1e-19
# 13        E + CO2 => E + CO2(v14)  excitation       3.8e+00     1.8e-19
# 14        E + CO2 => E + CO2(v15)  excitation       4.0e+00     8.3e-20
# 15        E + CO2 => E + CO2(v16)  excitation       4.3e+00     3.8e-20
# 16        E + CO2 => E + CO2(v17)  excitation       4.5e+00     1.8e-20
# 17        E + CO2 => E + CO2(v18)  excitation       4.8e+00     8.3e-21
# 18        E + CO2 => E + CO2(v19)  excitation       5.0e+00     4.0e-21
# 19        E + CO2 => E + CO2(v20)  excitation       5.2e+00     1.9e-21
# 20        E + CO2 => E + CO2(v21)  excitation       5.5e+00     9.3e-22
# 21     E + CO2(v1) => E + CO2(v2)  excitation       2.9e-01     3.7e-15
# 22     E + CO2(v1) => E + CO2(v3)  excitation       5.7e-01     1.6e-15
# 23     E + CO2(v1) => E + CO2(v4)  excitation       8.6e-01     7.3e-16
# 24     E + CO2(v1) => E + CO2(v5)  excitation       1.1e+00     3.6e-16
# 25     E + CO2(v1) => E + CO2(v6)  excitation       1.4e+00     1.8e-16
# 26     E + CO2(v1) => E + CO2(v7)  excitation       1.7e+00     8.5e-17
# 27     E + CO2(v1) => E + CO2(v8)  excitation       2.0e+00     4.2e-17
# 28     E + CO2(v1) => E + CO2(v9)  excitation       2.2e+00     2.0e-17
# 29    E + CO2(v1) => E + CO2(v10)  excitation       2.5e+00     9.7e-18
# ..                            ...         ...           ...         ...
# 201  E + CO2(v13) => E + CO2(v20)  excitation       1.7e+00     5.2e-17
# 202  E + CO2(v13) => E + CO2(v21)  excitation       1.9e+00     2.6e-17
# 203  E + CO2(v14) => E + CO2(v15)  excitation       2.5e-01     3.8e-15
# 204  E + CO2(v14) => E + CO2(v16)  excitation       4.9e-01     1.7e-15
# 205  E + CO2(v14) => E + CO2(v17)  excitation       7.3e-01     8.2e-16
# 206  E + CO2(v14) => E + CO2(v18)  excitation       9.7e-01     4.0e-16
# 207  E + CO2(v14) => E + CO2(v19)  excitation       1.2e+00     2.0e-16
# 208  E + CO2(v14) => E + CO2(v20)  excitation       1.4e+00     1.0e-16
# 209  E + CO2(v14) => E + CO2(v21)  excitation       1.7e+00     5.2e-17
# 210  E + CO2(v15) => E + CO2(v16)  excitation       2.4e-01     3.9e-15
# 211  E + CO2(v15) => E + CO2(v17)  excitation       4.9e-01     1.7e-15
# 212  E + CO2(v15) => E + CO2(v18)  excitation       7.3e-01     8.2e-16
# 213  E + CO2(v15) => E + CO2(v19)  excitation       9.6e-01     4.1e-16
# 214  E + CO2(v15) => E + CO2(v20)  excitation       1.2e+00     2.1e-16
# 215  E + CO2(v15) => E + CO2(v21)  excitation       1.4e+00     1.0e-16
# 216  E + CO2(v16) => E + CO2(v17)  excitation       2.4e-01     3.9e-15
# 217  E + CO2(v16) => E + CO2(v18)  excitation       4.8e-01     1.7e-15
# 218  E + CO2(v16) => E + CO2(v19)  excitation       7.2e-01     8.3e-16
# 219  E + CO2(v16) => E + CO2(v20)  excitation       9.5e-01     4.1e-16
# 220  E + CO2(v16) => E + CO2(v21)  excitation       1.2e+00     2.1e-16
# 221  E + CO2(v17) => E + CO2(v18)  excitation       2.4e-01     3.9e-15
# 222  E + CO2(v17) => E + CO2(v19)  excitation       4.7e-01     1.7e-15
# 223  E + CO2(v17) => E + CO2(v20)  excitation       7.1e-01     8.4e-16
# 224  E + CO2(v17) => E + CO2(v21)  excitation       9.4e-01     4.2e-16
# 225  E + CO2(v18) => E + CO2(v19)  excitation       2.4e-01     3.9e-15
# 226  E + CO2(v18) => E + CO2(v20)  excitation       4.7e-01     1.8e-15
# 227  E + CO2(v18) => E + CO2(v21)  excitation       7.0e-01     8.5e-16
# 228  E + CO2(v19) => E + CO2(v20)  excitation       2.3e-01     3.9e-15
# 229  E + CO2(v19) => E + CO2(v21)  excitation       4.6e-01     1.8e-15
# 230  E + CO2(v20) => E + CO2(v21)  excitation       2.3e-01     4.0e-15
#
#      energy lose
# 0        1.1e-15
# 1        9.0e-16
# 2        6.3e-16
# 3        4.0e-16
# 4        2.5e-16
# 5        1.4e-16
# 6        8.1e-17
# 7        4.5e-17
# 8        2.4e-17
# 9        1.2e-17
# 10       6.2e-18
# 11       3.0e-18
# 12       1.5e-18
# 13       7.0e-19
# 14       3.3e-19
# 15       1.6e-19
# 16       8.0e-20
# 17       3.9e-20
# 18       2.0e-20
# 19       1.0e-20
# 20       5.1e-21
# 21       1.1e-15
# 22       9.0e-16
# 23       6.3e-16
# 24       4.0e-16
# 25       2.5e-16
# 26       1.4e-16
# 27       8.2e-17
# 28       4.5e-17
# 29       2.4e-17
# ..           ...
# 201      8.7e-17
# 202      5.0e-17
# 203      9.5e-16
# 204      8.5e-16
# 205      6.0e-16
# 206      3.9e-16
# 207      2.5e-16
# 208      1.5e-16
# 209      8.7e-17
# 210      9.5e-16
# 211      8.4e-16
# 212      6.0e-16
# 213      3.9e-16
# 214      2.5e-16
# 215      1.5e-16
# 216      9.4e-16
# 217      8.3e-16
# 218      6.0e-16
# 219      3.9e-16
# 220      2.4e-16
# 221      9.3e-16
# 222      8.3e-16
# 223      6.0e-16
# 224      3.9e-16
# 225      9.2e-16
# 226      8.2e-16
# 227      5.9e-16
# 228      9.2e-16
# 229      8.2e-16
# 230      9.1e-16
#
# [231 rows x 5 columns]

# %%
1e-06*(7.14e-8 * exp(-177*Tg_K()^(-1/3.0) + 451*Tg_K()^(-2/3.0) ) *(1.000000)*(1.000000)*
           (0.5 * (3-exp(-2/3.0*(0.320000*0.082942*11604.5/4.441624* sqrt(22.004750/Tg_K())))) 
                *    exp(-2/3.0*(0.320000*0.082942*11604.5/4.441624* sqrt(22.004750/Tg_K())))
           )/(0.5*(3-exp(-2/3.0*(0.320000*0.082942*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
                *    exp(-2/3.0 *(0.320000*0.082942*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
      )"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-b3a1eba709b0> in <module>
# ----> 1 eedf.inelas_rctn_info.so
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'so'

# %%
1e-06*(7.14e-8*exp(-177*Tg_K()^(-1/3.0)+451*Tg_K()^(-2/3.0))*(0.700000)*(1.000000)*
       (0.5  *(3-exp(-2/3.0*(0.320000*0.082942*11604.5/4.587156* sqrt(17.116320/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.082942*11604.5/4.587156* sqrt(17.116320/Tg_K())))
       )/(0.5*(3-exp(-2/3.0*(0.320000*0.082942*11604.5/4.587156* sqrt(17.116320/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.082942*11604.5/4.587156* sqrt(17.116320/Tg_K())))))"

# %%
a = r"""1e-06*(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(1.000000)*(3.022449)*
       (0.5  *(3-exp(-2/3.0*(0.320000*0.205413*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.205413*11604.5/4.441624* sqrt(22.004750/Tg_K())))
       )/(0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
       + 8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(1.000000)*(3.006018)*
       (0.5  *(3-exp(-2/3.0*(0.320000*0.125192*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.125192*11604.5/4.441624* sqrt(22.004750/Tg_K())))
       )/(0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K())))) 
       + 1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(1.000000)*(2.910585)*
         (0.5*(3-exp(-2/3.0*(0.320000*0.044635*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
             *   exp(-2/3.0 *(0.320000*0.044635*11604.5/4.441624* sqrt(22.004750/Tg_K())))
         )/(0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K()))))
               *   exp(-2/3.0 *(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"""

# %%
from math import (exp, sqrt)
a = a.replace("Tg_K()", 'Tgas').replace('^', '**')

# %%
from sympy import simplify

# %%
simplify(a)
# Out:
# (2.576157426e-6*(1.5*exp(108.920699351559*sqrt(1/Tgas)) - 0.5)*(1.5*exp(327.324232296032*sqrt(1/Tgas)) - 0.5)*(1.5*exp(545.264984958087*sqrt(1/Tgas)) - 0.5)*exp(4*Tgas**(-1.0)*(274*Tgas**0.333333333333333 - 101*Tgas**0.666666666666667) + 15.9750707659336*sqrt(1/Tgas)) + 1.284540825e-6*(1.5*exp(108.920699351559*sqrt(1/Tgas)) - 0.5)*(1.5*exp(327.530783947506*sqrt(1/Tgas)) - 0.5)*(1.5*exp(537.068283345779*sqrt(1/Tgas)) - 0.5)*exp(Tgas**(-1.0)*(824*Tgas**0.333333333333333 - 407*Tgas**0.666666666666667) + 31.9553706876005*sqrt(1/Tgas)) + 4.16213655e-11*(1.5*exp(116.701683083051*sqrt(1/Tgas)) - 0.5)*(1.5*exp(327.530783947506*sqrt(1/Tgas)) - 0.5)*(1.5*exp(545.264984958087*sqrt(1/Tgas)) - 0.5)*exp(Tgas**(-1.0)*(685*Tgas**0.333333333333333 - 252*Tgas**0.666666666666667)))*exp(-15.5619674629847*sqrt(1/Tgas))/((1.5*exp(108.920699351559*sqrt(1/Tgas)) - 0.5)*(1.5*exp(327.530783947506*sqrt(1/Tgas)) - 0.5)*(1.5*exp(545.264984958087*sqrt(1/Tgas)) - 0.5))
