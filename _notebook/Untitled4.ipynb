# %%
r"""1e-06*(1e-12*exp(-150.7*Tg_K()^(-1/3.0))*(1.000000)*(6.190922)*(0.5*(3-exp(-2/3.0*(0.320000*0.249447*11604.5/4.742547* sqrt(14.005050/Tg_K()))))*exp(-2/3.0 *(0.320000*0.249447*11604.5/4.742547* sqrt(14.005050/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.265937*11604.5/4.742547* sqrt(14.005050/Tg_K()))))*exp(-2/3.0 *(0.320000*0.265937*11604.5/4.742547* sqrt(14.005050/Tg_K())))))"
"""
r"""(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(1.000000)*(6.113520)*
(0.5*(3-exp(-2/3.0*(0.320000*0.200712*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.200712*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(1.000000)*(6.030181)*
(0.5*(3-exp(-2/3.0*(0.320000*0.125073*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.125073*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(1.000000)*(5.572056)*
(0.5*(3-exp(-2/3.0*(0.320000*0.049098*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.049098*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"
"""
r"""
1e-06*(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(1.000000)*(22.684918)*
(0.5*(3-exp(-2/3.0*(0.320000*0.177205*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.177205*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(1.000000)*(21.429009)*
(0.5*(3-exp(-2/3.0*(0.320000*0.124477*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.124477*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
exp(-2/3.0 *(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(1.000000)*(16.064779)*(0.5*(3-exp(-2/3.0*(0.320000*0.071414*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.071414*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"
"""


_str = r"""(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(1.000000)*(2.007455)*
       (0.5*(3-exp(-2/3.0*(0.320000*0.206981*11604.5/4.441624*sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0*(0.320000*0.206981*11604.5/4.441624*sqrt(22.004750/Tg_K()))))/
       (0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624*sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0 *(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
       8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(1.000000)*(2.002004)*
       (0.5*(3-exp(-2/3.0*(0.320000*0.125231*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0*(0.320000*0.125231*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
       (0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0 *(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 
       1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(1.000000)*(1.969744)*
       (0.5*(3-exp(-2/3.0*(0.320000*0.043147*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0 *(0.320000*0.043147*11604.5/4.441624*sqrt(22.004750/Tg_K()))))/
       (0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
               exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624*sqrt(22.004750/Tg_K())))))"""

_str_1 = r"""((0.425)*exp((-407)*Tgas**(-1/3)+(824)*Tgas**(-2/3)))*
(0.5*(3-exp(-2/3*((0.32*0.20692900553361665*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.20692900553361665*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))/
(0.5*(3-exp(-2/3*((0.32*0.2085*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.2085*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))+
((0.857)*exp((-404)*Tgas**(-1/3)+(1096)*Tgas**(-2/3)))*
(0.5*(3-exp(-2/3*((0.32*0.12563814658967548*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.12563814658967548*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))/
(0.5*(3-exp(-2/3*((0.32*0.1257*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.1257*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))+
((1.43e-05)*exp((-252)*Tgas**(-1/3)+(685)*Tgas**(-2/3)))*
(0.5*(3-exp(-2/3*((0.32*0.0442927345988795*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.0442927345988795*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))/
(0.5*(3-exp(-2/3*((0.32*0.0428*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))*
        exp(-2/3*((0.32*0.0428*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))"""


(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(0.300000)*(13.606366)*
 (0.5*(3-exp(-2/3.0*(0.320000*0.189742*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.189742*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/
 (0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
        exp(-2/3.0 *(0.320000*0.208548*11604.5/4.587156* sqrt(17.116320/Tg_K())))) + 
 8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(0.300000)*(13.158055)*
 (0.5*(3-exp(-2/3.0*(0.320000*0.124795*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.124795*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/
 (0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.125271*11604.5/4.587156* sqrt(17.116320/Tg_K())))) + 
 1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(0.300000)*(10.976721)*
 (0.5*(3-exp(-2/3.0*(0.320000*0.059512*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.059512*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/
 (0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.041659*11604.5/4.587156* sqrt(17.116320/Tg_K())))))"


0.3 * ((((0.425)*exp((-407)*Tgas**(-1/3)+(824)*Tgas**(-2/3))) * 
(0.5*(3-exp(-2/3*((0.32 * 0.20692900553361665 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
 exp(-2/3*((0.32 * 0.20692900553361665 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas))))) / 
(0.5*(3-exp(-2/3*((0.32 *   0.2085 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
        exp(-2/3*((0.32 *   0.2085 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))) + 
       (((0.857)*exp((-404)*Tgas**(-1/3)+(1096)*Tgas**(-2/3))) * 
        (0.5*(3-exp(-2/3*((0.32 * 0.12563814658967548 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
         exp(-2/3*((0.32 * 0.12563814658967548 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas))))) / 
        (0.5*(3-exp(-2/3*((0.32 *   0.1257 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
         exp(-2/3*((0.32 *   0.1257 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))) + 
       (((1.43e-05)*exp((-252)*Tgas**(-1/3)+(685)*Tgas**(-2/3))) * 
        (0.5*(3-exp(-2/3*((0.32 * 0.0442927345988795 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
         exp(-2/3*((0.32 * 0.0442927345988795 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas))))) / 
        (0.5*(3-exp(-2/3*((0.32 *   0.0428 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas)))))*
         exp(-2/3*((0.32 *   0.0428 * 11604.5 / (4.587156) * sqrt((17.1164)/Tgas))))))) * 2 * 1e-6


4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(0.300000)*(4.045067)*
(0.5*(3-exp(-2/3.0*(0.320000*0.203846*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*
        exp(-2/3.0 *(0.320000*0.203846*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*exp(-2/3.0 *(0.320000*0.208548*11604.5/4.587156* sqrt(17.116320/Tg_K())))) + 8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(0.300000)*(4.012048)*(0.5*(3-exp(-2/3.0*(0.320000*0.125152*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*exp(-2/3.0 *(0.320000*0.125152*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*exp(-2/3.0 *(0.320000*0.125271*11604.5/4.587156* sqrt(17.116320/Tg_K())))) + 1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(0.300000)*(3.823795)*(0.5*(3-exp(-2/3.0*(0.320000*0.046123*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*exp(-2/3.0 *(0.320000*0.046123*11604.5/4.587156* sqrt(17.116320/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.587156* sqrt(17.116320/Tg_K()))))*exp(-2/3.0 *(0.320000*0.041659*11604.5/4.587156* sqrt(17.116320/Tg_K())))))"
# Out:
#   File "<ipython-input-1-48c1850e5fe9>", line 81
#     exp(-2/3.0 *(0.320000*0.041659*11604.5/4.587156* sqrt(17.116320/Tg_K())))))"
#                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
import math
eval(_str_1.replace('\n','').replace(' ', ''), {'Tgas':2000,'exp':math.exp, 'sqrt':math.sqrt})

# %%
eval(_str.replace('\n','').replace(' ', '').replace('Tg_K()','Tgas').replace('^', '**'), {'Tgas':2000,'exp':math.exp, 'sqrt':math.sqrt})

# %%
_str = _str.replace('exp(-2/3.0*(0.320000*0.206981*11604.5/4.441624*sqrt(22.004750/Tg_K())))', 'exp(a)')
_str = _str.replace('exp(-2/3.0*(0.320000*0.125231*11604.5/4.441624* sqrt(22.004750/Tg_K())))', 'exp(b)')
_str

# %%
_str_0 = r"""1e-06*(4.25e-1*exp(-407*Tg_K()^(-1/3.0)+824*Tg_K()^(-2/3.0))*(1.000000)*(2.007455)*
         (0.5*(3-exp(-2/3.0*(0.320000*0.206981*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
                 exp(-2/3.0*(0.320000*0.206981*11604.5/4.441624*sqrt(22.004750/Tg_K()))))/
         (0.5*(3-exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
                 exp(-2/3.0*(0.320000*0.208548*11604.5/4.441624* sqrt(22.004750/Tg_K())))) +
         8.57e-1*exp(-404*Tg_K()^(-1/3.0)+1096*Tg_K()^(-2/3.0))*(1.000000)*(2.002004)*
         (0.5*(3-exp(-2/3.0*(0.320000*0.125231*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.125231*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.125271*11604.5/4.441624* sqrt(22.004750/Tg_K())))) + 1.43e-5*exp(-252*Tg_K()^(-1/3.0)+685*Tg_K()^(-2/3.0))*(1.000000)*(1.969744)*(0.5*(3-exp(-2/3.0*(0.320000*0.043147*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.043147*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/(0.5*(3-exp(-2/3.0*(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*exp(-2/3.0 *(0.320000*0.041659*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"
"""

# %%
(((0.425)*exp((-407)*Tgas**(-1/3)+(824)*Tgas**(-2/3)))*
 (0.5*(3-exp(-2/3*(0.32*2419.397640989312/(4.441624)*sqrt((22.00475)/Tgas))))*
         exp(-2/3*(0.32*2419.397640989312/(4.441624)*sqrt((22.00475)/Tgas))))/
 (0.5*(3-exp(-2/3*(0.32*2419.40/(4.441624)*sqrt((22.00475)/Tgas))))*
         exp(-2/3*(0.32*2419.40/(4.441624)*sqrt((22.00475)/Tgas)))))

# %%
(((0.425)*exp((-407)*Tgas**(-1/3)+(824)*Tgas**(-2/3)))*
 (0.5*(3-exp(-2/3*(0.32*0.20692900553361665*11604.5/(4.441624)*sqrt((22.00475)/Tgas))))*
         exp(-2/3*(0.32*0.20692900553361665*11604.5/(4.441624)*sqrt((22.00475)/Tgas))))/
 (0.5*(3-exp(-2/3*(0.32*0.2085*11604.5/(4.441624)*sqrt((22.00475)/Tgas))))*
         exp(-2/3*(0.32*0.2085*11604.5/(4.441624)*sqrt((22.00475)/Tgas)))))

# %%
1.32e-10*sqrt(Tg_K()/300)*250/Tg_K()*(1.000000)*(1.000000*2.010611)*
(0.5*(3-exp(-2/3.0*(0.320000*0.003095*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
        exp(-2/3.0*(0.320000*0.003095*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
(0.5*(3-exp(-2/3.0*(0.320000*0.000000*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
        exp(-2/3.0 *(0.320000*0.000000*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"

# %%
(1.32e-10*sqrt(Tg_K()/300)*250/Tg_K()*(1.000000)*(1.000000*2.010611)*
 (0.5*(3-exp(-2/3.0*(0.320000*0.003095*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.003095*11604.5/4.441624* sqrt(22.004750/Tg_K()))))/
 (0.5*(3-exp(-2/3.0*(0.320000*0.000000*11604.5/4.441624* sqrt(22.004750/Tg_K()))))*
         exp(-2/3.0 *(0.320000*0.000000*11604.5/4.441624* sqrt(22.004750/Tg_K())))))"
1e-6 * (1.32e-10*sqrt(Tgas/300)*250/Tgas) * 
(0.5*(3-exp(-2/3*((0.32 *   0.0030921658830666 * 11604.5 / (4.441624) * sqrt((22.005)/Tgas)))))*
        exp(-2/3*((0.32 *   0.0030921658830666 * 11604.5 / (4.441624) * sqrt((22.005)/Tgas))))) / 
(0.5*(3-exp(-2/3*((0.32 * 0.0000 * 11604.5 / (4.441624) * sqrt((22.005)/Tgas)))))*
        exp(-2/3*((0.32 * 0.0000 * 11604.5 / (4.441624) * sqrt((22.005)/Tgas)))))
