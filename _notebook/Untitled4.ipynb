# %%
# %cd ..

# %%
import yaml

# %%
with open('_yaml/test.yaml') as f:
    rctn = yaml.load_all(f)
    rctn = [_ for _ in rctn]
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# <ipython-input-3-33720fc3d251> in <module>
#       1 with open('_yaml/test.yaml') as f:
#       2     rctn = yaml.load_all(f)
# ----> 3     rctn = [_ for _ in rctn]
#
# <ipython-input-3-33720fc3d251> in <listcomp>(.0)
#       1 with open('_yaml/test.yaml') as f:
#       2     rctn = yaml.load_all(f)
# ----> 3     rctn = [_ for _ in rctn]
#
# ~\Anaconda3\lib\site-packages\yaml\__init__.py in load_all(stream, Loader)
#      82     try:
#      83         while loader.check_data():
# ---> 84             yield loader.get_data()
#      85     finally:
#      86         loader.dispose()
#
# ~\Anaconda3\lib\site-packages\yaml\constructor.py in get_data(self)
#      29         # Construct and return the next document.
#      30         if self.check_node():
# ---> 31             return self.construct_document(self.get_node())
#      32
# ...

# %%
rctn[-1]
