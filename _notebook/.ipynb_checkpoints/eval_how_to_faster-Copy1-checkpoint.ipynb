# %%
# %cd "C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry"
# Out:
# C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry

# %%
import time
import timeit
import math
import numpy as np
import timeit
import numba as nb
import importlib

# %%
_number = int(1e3)

with open("_cache/cache.txt") as f:
    # multi_expr = [_.strip() for i, _ in enumerate(f.readlines()) if i < _number]
    multi_expr = ["(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)"]*_number


multi_expr_compiled = compile(f"[{','.join(multi_expr)}]",'<string>','eval')

# %%
multi_expr
# Out:
# ['(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
# ...
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)',
#  '(3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)']

# %%
# %timeit eval(multi_expr_compiled,{"__builtins__":__builtins__,"exp":math.exp,"sqrt":math.sqrt,"Tgas":2000})
# Out:
# 1.46 ms ± 54.8 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
with open(r"_cache/cache_template.py") as f:
    _str = f.readlines()
_str = "".join(_str)
_list = [f"value = {_}" for i,_ in enumerate(multi_expr)]
_multi_expr_str = "\n    ".join(_list)

# %%
_str_to_write = _str.replace('"""__REPLACE__"""', f"{_multi_expr_str}")

# %%
with open(r"_cache/cache.py", "r+") as f:
    f.seek(0)
    f.truncate()
    f.write(_str_to_write)

# %%
start = time.time()
from _cache import cache
import importlib
importlib.reload(cache)
end = time.time()

# %%
cache.test.inspect_types()
# Out:
# test (float64, float64)
# --------------------------------------------------------------------------------
# # File: C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py
# # --- LINE 20 ---
# # label 0
#
# @numba.jit("float64(float64, float64)", nopython=True, nogil=False, parallel=True, fastmath=True)
#
# # --- LINE 21 ---
#
# def test(value, Tgas):
#
#     # --- LINE 22 ---
#     #   Tgas = arg(1, name=Tgas)  :: float64
#     #   $0.7 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.8 = const(int, -52536)  :: int64
#     #   $0.10 = $const0.8 / Tgas  :: float64
#     #   del $const0.8
#     #   $0.11 = call $0.7($0.10, func=$0.7, args=[Var($0.10, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (22))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.7
#     #   del $0.11
#     #   del $0.10
#     #   $0.14 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.15 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.16 = const(int, 51994)  :: int64
#     #   $const0.17 = const(float, 52534.079999999994)  :: float64
#     #   $0.18 = call $0.15($const0.16, $const0.17, func=$0.15, args=[Var($const0.16, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (22)), Var($const0.17, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (22))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.17
#     #   del $const0.16
#     #   del $0.15
#     #   $0.20 = $0.18 / Tgas  :: float64
#     #   del $0.18
#     #   $0.21 = call $0.14($0.20, func=$0.14, args=[Var($0.20, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (22))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21
#     #   del $0.20
#     #   del $0.14
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 23 ---
#     #   $0.29 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.30 = const(int, -52536)  :: int64
#     #   $0.32 = $const0.30 / Tgas  :: float64
#     #   del $const0.30
#     #   $0.33 = call $0.29($0.32, func=$0.29, args=[Var($0.32, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (23))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.33
#     #   del $0.32
#     #   del $0.29
#     #   $0.36 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.37 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.38 = const(int, 51994)  :: int64
#     #   $const0.39 = const(float, 52534.079999999994)  :: float64
#     #   $0.40 = call $0.37($const0.38, $const0.39, func=$0.37, args=[Var($const0.38, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (23)), Var($const0.39, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (23))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.39
#     #   del $const0.38
#     #   del $0.37
#     #   $0.42 = $0.40 / Tgas  :: float64
#     #   del $0.40
#     #   $0.43 = call $0.36($0.42, func=$0.36, args=[Var($0.42, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (23))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.43
#     #   del $0.42
#     #   del $0.36
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 24 ---
#     #   $0.51 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.52 = const(int, -52536)  :: int64
#     #   $0.54 = $const0.52 / Tgas  :: float64
#     #   del $const0.52
#     #   $0.55 = call $0.51($0.54, func=$0.51, args=[Var($0.54, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (24))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.55
#     #   del $0.54
#     #   del $0.51
#     #   $0.58 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.59 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.60 = const(int, 51994)  :: int64
#     #   $const0.61 = const(float, 52534.079999999994)  :: float64
#     #   $0.62 = call $0.59($const0.60, $const0.61, func=$0.59, args=[Var($const0.60, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (24)), Var($const0.61, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (24))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.61
#     #   del $const0.60
#     #   del $0.59
#     #   $0.64 = $0.62 / Tgas  :: float64
#     #   del $0.62
#     #   $0.65 = call $0.58($0.64, func=$0.58, args=[Var($0.64, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (24))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.65
#     #   del $0.64
#     #   del $0.58
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 25 ---
#     #   $0.73 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.74 = const(int, -52536)  :: int64
#     #   $0.76 = $const0.74 / Tgas  :: float64
#     #   del $const0.74
#     #   $0.77 = call $0.73($0.76, func=$0.73, args=[Var($0.76, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (25))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.77
#     #   del $0.76
#     #   del $0.73
#     #   $0.80 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.81 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.82 = const(int, 51994)  :: int64
#     #   $const0.83 = const(float, 52534.079999999994)  :: float64
#     #   $0.84 = call $0.81($const0.82, $const0.83, func=$0.81, args=[Var($const0.82, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (25)), Var($const0.83, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (25))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.83
#     #   del $const0.82
#     #   del $0.81
#     #   $0.86 = $0.84 / Tgas  :: float64
#     #   del $0.84
#     #   $0.87 = call $0.80($0.86, func=$0.80, args=[Var($0.86, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (25))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.87
#     #   del $0.86
#     #   del $0.80
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 26 ---
#     #   $0.95 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.96 = const(int, -52536)  :: int64
#     #   $0.98 = $const0.96 / Tgas  :: float64
#     #   del $const0.96
#     #   $0.99 = call $0.95($0.98, func=$0.95, args=[Var($0.98, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (26))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.99
#     #   del $0.98
#     #   del $0.95
#     #   $0.102 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.103 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.104 = const(int, 51994)  :: int64
#     #   $const0.105 = const(float, 52534.079999999994)  :: float64
#     #   $0.106 = call $0.103($const0.104, $const0.105, func=$0.103, args=[Var($const0.104, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (26)), Var($const0.105, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (26))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.105
#     #   del $const0.104
#     #   del $0.103
#     #   $0.108 = $0.106 / Tgas  :: float64
#     #   del $0.106
#     #   $0.109 = call $0.102($0.108, func=$0.102, args=[Var($0.108, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (26))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.109
#     #   del $0.108
#     #   del $0.102
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 27 ---
#     #   $0.117 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.118 = const(int, -52536)  :: int64
#     #   $0.120 = $const0.118 / Tgas  :: float64
#     #   del $const0.118
#     #   $0.121 = call $0.117($0.120, func=$0.117, args=[Var($0.120, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (27))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.121
#     #   del $0.120
#     #   del $0.117
#     #   $0.124 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.125 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.126 = const(int, 51994)  :: int64
#     #   $const0.127 = const(float, 52534.079999999994)  :: float64
#     #   $0.128 = call $0.125($const0.126, $const0.127, func=$0.125, args=[Var($const0.126, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (27)), Var($const0.127, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (27))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.127
#     #   del $const0.126
#     #   del $0.125
#     #   $0.130 = $0.128 / Tgas  :: float64
#     #   del $0.128
#     #   $0.131 = call $0.124($0.130, func=$0.124, args=[Var($0.130, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (27))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.131
#     #   del $0.130
#     #   del $0.124
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 28 ---
#     #   $0.139 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.140 = const(int, -52536)  :: int64
#     #   $0.142 = $const0.140 / Tgas  :: float64
#     #   del $const0.140
#     #   $0.143 = call $0.139($0.142, func=$0.139, args=[Var($0.142, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (28))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.143
#     #   del $0.142
#     #   del $0.139
#     #   $0.146 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.147 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.148 = const(int, 51994)  :: int64
#     #   $const0.149 = const(float, 52534.079999999994)  :: float64
#     #   $0.150 = call $0.147($const0.148, $const0.149, func=$0.147, args=[Var($const0.148, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (28)), Var($const0.149, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (28))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.149
#     #   del $const0.148
#     #   del $0.147
#     #   $0.152 = $0.150 / Tgas  :: float64
#     #   del $0.150
#     #   $0.153 = call $0.146($0.152, func=$0.146, args=[Var($0.152, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (28))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.153
#     #   del $0.152
#     #   del $0.146
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 29 ---
#     #   $0.161 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.162 = const(int, -52536)  :: int64
#     #   $0.164 = $const0.162 / Tgas  :: float64
#     #   del $const0.162
#     #   $0.165 = call $0.161($0.164, func=$0.161, args=[Var($0.164, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (29))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.165
#     #   del $0.164
#     #   del $0.161
#     #   $0.168 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.169 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.170 = const(int, 51994)  :: int64
#     #   $const0.171 = const(float, 52534.079999999994)  :: float64
#     #   $0.172 = call $0.169($const0.170, $const0.171, func=$0.169, args=[Var($const0.170, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (29)), Var($const0.171, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (29))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.171
#     #   del $const0.170
#     #   del $0.169
#     #   $0.174 = $0.172 / Tgas  :: float64
#     #   del $0.172
#     #   $0.175 = call $0.168($0.174, func=$0.168, args=[Var($0.174, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (29))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.175
#     #   del $0.174
#     #   del $0.168
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 30 ---
#     #   $0.183 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.184 = const(int, -52536)  :: int64
#     #   $0.186 = $const0.184 / Tgas  :: float64
#     #   del $const0.184
#     #   $0.187 = call $0.183($0.186, func=$0.183, args=[Var($0.186, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (30))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.187
#     #   del $0.186
#     #   del $0.183
#     #   $0.190 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.191 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.192 = const(int, 51994)  :: int64
#     #   $const0.193 = const(float, 52534.079999999994)  :: float64
#     #   $0.194 = call $0.191($const0.192, $const0.193, func=$0.191, args=[Var($const0.192, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (30)), Var($const0.193, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (30))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.193
#     #   del $const0.192
#     #   del $0.191
#     #   $0.196 = $0.194 / Tgas  :: float64
#     #   del $0.194
#     #   $0.197 = call $0.190($0.196, func=$0.190, args=[Var($0.196, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (30))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.197
#     #   del $0.196
#     #   del $0.190
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 31 ---
#     #   $0.205 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.206 = const(int, -52536)  :: int64
#     #   $0.208 = $const0.206 / Tgas  :: float64
#     #   del $const0.206
#     #   $0.209 = call $0.205($0.208, func=$0.205, args=[Var($0.208, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (31))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.209
#     #   del $0.208
#     #   del $0.205
#     #   $0.212 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.213 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.214 = const(int, 51994)  :: int64
#     #   $const0.215 = const(float, 52534.079999999994)  :: float64
#     #   $0.216 = call $0.213($const0.214, $const0.215, func=$0.213, args=[Var($const0.214, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (31)), Var($const0.215, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (31))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.215
#     #   del $const0.214
#     #   del $0.213
#     #   $0.218 = $0.216 / Tgas  :: float64
#     #   del $0.216
#     #   $0.219 = call $0.212($0.218, func=$0.212, args=[Var($0.218, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (31))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.219
#     #   del $0.218
#     #   del $0.212
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 32 ---
#     #   $0.227 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.228 = const(int, -52536)  :: int64
#     #   $0.230 = $const0.228 / Tgas  :: float64
#     #   del $const0.228
#     #   $0.231 = call $0.227($0.230, func=$0.227, args=[Var($0.230, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (32))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.231
#     #   del $0.230
#     #   del $0.227
#     #   $0.234 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.235 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.236 = const(int, 51994)  :: int64
#     #   $const0.237 = const(float, 52534.079999999994)  :: float64
#     #   $0.238 = call $0.235($const0.236, $const0.237, func=$0.235, args=[Var($const0.236, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (32)), Var($const0.237, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (32))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.237
#     #   del $const0.236
#     #   del $0.235
#     #   $0.240 = $0.238 / Tgas  :: float64
#     #   del $0.238
#     #   $0.241 = call $0.234($0.240, func=$0.234, args=[Var($0.240, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (32))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.241
#     #   del $0.240
#     #   del $0.234
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 33 ---
#     #   $0.249 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.250 = const(int, -52536)  :: int64
#     #   $0.252 = $const0.250 / Tgas  :: float64
#     #   del $const0.250
#     #   $0.253 = call $0.249($0.252, func=$0.249, args=[Var($0.252, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (33))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.253
#     #   del $0.252
#     #   del $0.249
#     #   $0.256 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.257 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.258 = const(int, 51994)  :: int64
#     #   $const0.259 = const(float, 52534.079999999994)  :: float64
#     #   $0.260 = call $0.257($const0.258, $const0.259, func=$0.257, args=[Var($const0.258, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (33)), Var($const0.259, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (33))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.259
#     #   del $const0.258
#     #   del $0.257
#     #   $0.262 = $0.260 / Tgas  :: float64
#     #   del $0.260
#     #   $0.263 = call $0.256($0.262, func=$0.256, args=[Var($0.262, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (33))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.263
#     #   del $0.262
#     #   del $0.256
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 34 ---
#     #   $0.271 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.272 = const(int, -52536)  :: int64
#     #   $0.274 = $const0.272 / Tgas  :: float64
#     #   del $const0.272
#     #   $0.275 = call $0.271($0.274, func=$0.271, args=[Var($0.274, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (34))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.275
#     #   del $0.274
#     #   del $0.271
#     #   $0.278 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.279 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.280 = const(int, 51994)  :: int64
#     #   $const0.281 = const(float, 52534.079999999994)  :: float64
#     #   $0.282 = call $0.279($const0.280, $const0.281, func=$0.279, args=[Var($const0.280, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (34)), Var($const0.281, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (34))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.281
#     #   del $const0.280
#     #   del $0.279
#     #   $0.284 = $0.282 / Tgas  :: float64
#     #   del $0.282
#     #   $0.285 = call $0.278($0.284, func=$0.278, args=[Var($0.284, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (34))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.285
#     #   del $0.284
#     #   del $0.278
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 35 ---
#     #   $0.293 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.294 = const(int, -52536)  :: int64
#     #   $0.296 = $const0.294 / Tgas  :: float64
#     #   del $const0.294
#     #   $0.297 = call $0.293($0.296, func=$0.293, args=[Var($0.296, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (35))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.297
#     #   del $0.296
#     #   del $0.293
#     #   $0.300 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.301 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.302 = const(int, 51994)  :: int64
#     #   $const0.303 = const(float, 52534.079999999994)  :: float64
#     #   $0.304 = call $0.301($const0.302, $const0.303, func=$0.301, args=[Var($const0.302, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (35)), Var($const0.303, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (35))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.303
#     #   del $const0.302
#     #   del $0.301
#     #   $0.306 = $0.304 / Tgas  :: float64
#     #   del $0.304
#     #   $0.307 = call $0.300($0.306, func=$0.300, args=[Var($0.306, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (35))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.307
#     #   del $0.306
#     #   del $0.300
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 36 ---
#     #   $0.315 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.316 = const(int, -52536)  :: int64
#     #   $0.318 = $const0.316 / Tgas  :: float64
#     #   del $const0.316
#     #   $0.319 = call $0.315($0.318, func=$0.315, args=[Var($0.318, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (36))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.319
#     #   del $0.318
#     #   del $0.315
#     #   $0.322 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.323 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.324 = const(int, 51994)  :: int64
#     #   $const0.325 = const(float, 52534.079999999994)  :: float64
#     #   $0.326 = call $0.323($const0.324, $const0.325, func=$0.323, args=[Var($const0.324, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (36)), Var($const0.325, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (36))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.325
#     #   del $const0.324
#     #   del $0.323
#     #   $0.328 = $0.326 / Tgas  :: float64
#     #   del $0.326
#     #   $0.329 = call $0.322($0.328, func=$0.322, args=[Var($0.328, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (36))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.329
#     #   del $0.328
#     #   del $0.322
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 37 ---
#     #   $0.337 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.338 = const(int, -52536)  :: int64
#     #   $0.340 = $const0.338 / Tgas  :: float64
#     #   del $const0.338
#     #   $0.341 = call $0.337($0.340, func=$0.337, args=[Var($0.340, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (37))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.341
#     #   del $0.340
#     #   del $0.337
#     #   $0.344 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.345 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.346 = const(int, 51994)  :: int64
#     #   $const0.347 = const(float, 52534.079999999994)  :: float64
#     #   $0.348 = call $0.345($const0.346, $const0.347, func=$0.345, args=[Var($const0.346, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (37)), Var($const0.347, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (37))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.347
#     #   del $const0.346
#     #   del $0.345
#     #   $0.350 = $0.348 / Tgas  :: float64
#     #   del $0.348
#     #   $0.351 = call $0.344($0.350, func=$0.344, args=[Var($0.350, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (37))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.351
#     #   del $0.350
#     #   del $0.344
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 38 ---
#     #   $0.359 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.360 = const(int, -52536)  :: int64
#     #   $0.362 = $const0.360 / Tgas  :: float64
#     #   del $const0.360
#     #   $0.363 = call $0.359($0.362, func=$0.359, args=[Var($0.362, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (38))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.363
#     #   del $0.362
#     #   del $0.359
#     #   $0.366 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.367 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.368 = const(int, 51994)  :: int64
#     #   $const0.369 = const(float, 52534.079999999994)  :: float64
#     #   $0.370 = call $0.367($const0.368, $const0.369, func=$0.367, args=[Var($const0.368, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (38)), Var($const0.369, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (38))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.369
#     #   del $const0.368
#     #   del $0.367
#     #   $0.372 = $0.370 / Tgas  :: float64
#     #   del $0.370
#     #   $0.373 = call $0.366($0.372, func=$0.366, args=[Var($0.372, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (38))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.373
#     #   del $0.372
#     #   del $0.366
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 39 ---
#     #   $0.381 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.382 = const(int, -52536)  :: int64
#     #   $0.384 = $const0.382 / Tgas  :: float64
#     #   del $const0.382
#     #   $0.385 = call $0.381($0.384, func=$0.381, args=[Var($0.384, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (39))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.385
#     #   del $0.384
#     #   del $0.381
#     #   $0.388 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.389 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.390 = const(int, 51994)  :: int64
#     #   $const0.391 = const(float, 52534.079999999994)  :: float64
#     #   $0.392 = call $0.389($const0.390, $const0.391, func=$0.389, args=[Var($const0.390, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (39)), Var($const0.391, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (39))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.391
#     #   del $const0.390
#     #   del $0.389
#     #   $0.394 = $0.392 / Tgas  :: float64
#     #   del $0.392
#     #   $0.395 = call $0.388($0.394, func=$0.388, args=[Var($0.394, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (39))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.395
#     #   del $0.394
#     #   del $0.388
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 40 ---
#     #   $0.403 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.404 = const(int, -52536)  :: int64
#     #   $0.406 = $const0.404 / Tgas  :: float64
#     #   del $const0.404
#     #   $0.407 = call $0.403($0.406, func=$0.403, args=[Var($0.406, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (40))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.407
#     #   del $0.406
#     #   del $0.403
#     #   $0.410 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.411 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.412 = const(int, 51994)  :: int64
#     #   $const0.413 = const(float, 52534.079999999994)  :: float64
#     #   $0.414 = call $0.411($const0.412, $const0.413, func=$0.411, args=[Var($const0.412, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (40)), Var($const0.413, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (40))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.413
#     #   del $const0.412
#     #   del $0.411
#     #   $0.416 = $0.414 / Tgas  :: float64
#     #   del $0.414
#     #   $0.417 = call $0.410($0.416, func=$0.410, args=[Var($0.416, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (40))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.417
#     #   del $0.416
#     #   del $0.410
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 41 ---
#     #   $0.425 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.426 = const(int, -52536)  :: int64
#     #   $0.428 = $const0.426 / Tgas  :: float64
#     #   del $const0.426
#     #   $0.429 = call $0.425($0.428, func=$0.425, args=[Var($0.428, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (41))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.429
#     #   del $0.428
#     #   del $0.425
#     #   $0.432 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.433 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.434 = const(int, 51994)  :: int64
#     #   $const0.435 = const(float, 52534.079999999994)  :: float64
#     #   $0.436 = call $0.433($const0.434, $const0.435, func=$0.433, args=[Var($const0.434, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (41)), Var($const0.435, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (41))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.435
#     #   del $const0.434
#     #   del $0.433
#     #   $0.438 = $0.436 / Tgas  :: float64
#     #   del $0.436
#     #   $0.439 = call $0.432($0.438, func=$0.432, args=[Var($0.438, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (41))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.439
#     #   del $0.438
#     #   del $0.432
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 42 ---
#     #   $0.447 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.448 = const(int, -52536)  :: int64
#     #   $0.450 = $const0.448 / Tgas  :: float64
#     #   del $const0.448
#     #   $0.451 = call $0.447($0.450, func=$0.447, args=[Var($0.450, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (42))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.451
#     #   del $0.450
#     #   del $0.447
#     #   $0.454 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.455 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.456 = const(int, 51994)  :: int64
#     #   $const0.457 = const(float, 52534.079999999994)  :: float64
#     #   $0.458 = call $0.455($const0.456, $const0.457, func=$0.455, args=[Var($const0.456, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (42)), Var($const0.457, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (42))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.457
#     #   del $const0.456
#     #   del $0.455
#     #   $0.460 = $0.458 / Tgas  :: float64
#     #   del $0.458
#     #   $0.461 = call $0.454($0.460, func=$0.454, args=[Var($0.460, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (42))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.461
#     #   del $0.460
#     #   del $0.454
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 43 ---
#     #   $0.469 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.470 = const(int, -52536)  :: int64
#     #   $0.472 = $const0.470 / Tgas  :: float64
#     #   del $const0.470
#     #   $0.473 = call $0.469($0.472, func=$0.469, args=[Var($0.472, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (43))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.473
#     #   del $0.472
#     #   del $0.469
#     #   $0.476 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.477 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.478 = const(int, 51994)  :: int64
#     #   $const0.479 = const(float, 52534.079999999994)  :: float64
#     #   $0.480 = call $0.477($const0.478, $const0.479, func=$0.477, args=[Var($const0.478, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (43)), Var($const0.479, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (43))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.479
#     #   del $const0.478
#     #   del $0.477
#     #   $0.482 = $0.480 / Tgas  :: float64
#     #   del $0.480
#     #   $0.483 = call $0.476($0.482, func=$0.476, args=[Var($0.482, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (43))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.483
#     #   del $0.482
#     #   del $0.476
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 44 ---
#     #   $0.491 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.492 = const(int, -52536)  :: int64
#     #   $0.494 = $const0.492 / Tgas  :: float64
#     #   del $const0.492
#     #   $0.495 = call $0.491($0.494, func=$0.491, args=[Var($0.494, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (44))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.495
#     #   del $0.494
#     #   del $0.491
#     #   $0.498 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.499 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.500 = const(int, 51994)  :: int64
#     #   $const0.501 = const(float, 52534.079999999994)  :: float64
#     #   $0.502 = call $0.499($const0.500, $const0.501, func=$0.499, args=[Var($const0.500, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (44)), Var($const0.501, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (44))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.501
#     #   del $const0.500
#     #   del $0.499
#     #   $0.504 = $0.502 / Tgas  :: float64
#     #   del $0.502
#     #   $0.505 = call $0.498($0.504, func=$0.498, args=[Var($0.504, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (44))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.505
#     #   del $0.504
#     #   del $0.498
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 45 ---
#     #   $0.513 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.514 = const(int, -52536)  :: int64
#     #   $0.516 = $const0.514 / Tgas  :: float64
#     #   del $const0.514
#     #   $0.517 = call $0.513($0.516, func=$0.513, args=[Var($0.516, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (45))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.517
#     #   del $0.516
#     #   del $0.513
#     #   $0.520 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.521 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.522 = const(int, 51994)  :: int64
#     #   $const0.523 = const(float, 52534.079999999994)  :: float64
#     #   $0.524 = call $0.521($const0.522, $const0.523, func=$0.521, args=[Var($const0.522, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (45)), Var($const0.523, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (45))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.523
#     #   del $const0.522
#     #   del $0.521
#     #   $0.526 = $0.524 / Tgas  :: float64
#     #   del $0.524
#     #   $0.527 = call $0.520($0.526, func=$0.520, args=[Var($0.526, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (45))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.527
#     #   del $0.526
#     #   del $0.520
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 46 ---
#     #   $0.535 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.536 = const(int, -52536)  :: int64
#     #   $0.538 = $const0.536 / Tgas  :: float64
#     #   del $const0.536
#     #   $0.539 = call $0.535($0.538, func=$0.535, args=[Var($0.538, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (46))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.539
#     #   del $0.538
#     #   del $0.535
#     #   $0.542 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.543 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.544 = const(int, 51994)  :: int64
#     #   $const0.545 = const(float, 52534.079999999994)  :: float64
#     #   $0.546 = call $0.543($const0.544, $const0.545, func=$0.543, args=[Var($const0.544, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (46)), Var($const0.545, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (46))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.545
#     #   del $const0.544
#     #   del $0.543
#     #   $0.548 = $0.546 / Tgas  :: float64
#     #   del $0.546
#     #   $0.549 = call $0.542($0.548, func=$0.542, args=[Var($0.548, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (46))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.549
#     #   del $0.548
#     #   del $0.542
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 47 ---
#     #   $0.557 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.558 = const(int, -52536)  :: int64
#     #   $0.560 = $const0.558 / Tgas  :: float64
#     #   del $const0.558
#     #   $0.561 = call $0.557($0.560, func=$0.557, args=[Var($0.560, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (47))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.561
#     #   del $0.560
#     #   del $0.557
#     #   $0.564 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.565 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.566 = const(int, 51994)  :: int64
#     #   $const0.567 = const(float, 52534.079999999994)  :: float64
#     #   $0.568 = call $0.565($const0.566, $const0.567, func=$0.565, args=[Var($const0.566, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (47)), Var($const0.567, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (47))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.567
#     #   del $const0.566
#     #   del $0.565
#     #   $0.570 = $0.568 / Tgas  :: float64
#     #   del $0.568
#     #   $0.571 = call $0.564($0.570, func=$0.564, args=[Var($0.570, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (47))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.571
#     #   del $0.570
#     #   del $0.564
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 48 ---
#     #   $0.579 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.580 = const(int, -52536)  :: int64
#     #   $0.582 = $const0.580 / Tgas  :: float64
#     #   del $const0.580
#     #   $0.583 = call $0.579($0.582, func=$0.579, args=[Var($0.582, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (48))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.583
#     #   del $0.582
#     #   del $0.579
#     #   $0.586 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.587 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.588 = const(int, 51994)  :: int64
#     #   $const0.589 = const(float, 52534.079999999994)  :: float64
#     #   $0.590 = call $0.587($const0.588, $const0.589, func=$0.587, args=[Var($const0.588, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (48)), Var($const0.589, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (48))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.589
#     #   del $const0.588
#     #   del $0.587
#     #   $0.592 = $0.590 / Tgas  :: float64
#     #   del $0.590
#     #   $0.593 = call $0.586($0.592, func=$0.586, args=[Var($0.592, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (48))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.593
#     #   del $0.592
#     #   del $0.586
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 49 ---
#     #   $0.601 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.602 = const(int, -52536)  :: int64
#     #   $0.604 = $const0.602 / Tgas  :: float64
#     #   del $const0.602
#     #   $0.605 = call $0.601($0.604, func=$0.601, args=[Var($0.604, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (49))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.605
#     #   del $0.604
#     #   del $0.601
#     #   $0.608 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.609 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.610 = const(int, 51994)  :: int64
#     #   $const0.611 = const(float, 52534.079999999994)  :: float64
#     #   $0.612 = call $0.609($const0.610, $const0.611, func=$0.609, args=[Var($const0.610, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (49)), Var($const0.611, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (49))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.611
#     #   del $const0.610
#     #   del $0.609
#     #   $0.614 = $0.612 / Tgas  :: float64
#     #   del $0.612
#     #   $0.615 = call $0.608($0.614, func=$0.608, args=[Var($0.614, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (49))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.615
#     #   del $0.614
#     #   del $0.608
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 50 ---
#     #   $0.623 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.624 = const(int, -52536)  :: int64
#     #   $0.626 = $const0.624 / Tgas  :: float64
#     #   del $const0.624
#     #   $0.627 = call $0.623($0.626, func=$0.623, args=[Var($0.626, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (50))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.627
#     #   del $0.626
#     #   del $0.623
#     #   $0.630 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.631 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.632 = const(int, 51994)  :: int64
#     #   $const0.633 = const(float, 52534.079999999994)  :: float64
#     #   $0.634 = call $0.631($const0.632, $const0.633, func=$0.631, args=[Var($const0.632, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (50)), Var($const0.633, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (50))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.633
#     #   del $const0.632
#     #   del $0.631
#     #   $0.636 = $0.634 / Tgas  :: float64
#     #   del $0.634
#     #   $0.637 = call $0.630($0.636, func=$0.630, args=[Var($0.636, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (50))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.637
#     #   del $0.636
#     #   del $0.630
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 51 ---
#     #   $0.645 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.646 = const(int, -52536)  :: int64
#     #   $0.648 = $const0.646 / Tgas  :: float64
#     #   del $const0.646
#     #   $0.649 = call $0.645($0.648, func=$0.645, args=[Var($0.648, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (51))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.649
#     #   del $0.648
#     #   del $0.645
#     #   $0.652 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.653 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.654 = const(int, 51994)  :: int64
#     #   $const0.655 = const(float, 52534.079999999994)  :: float64
#     #   $0.656 = call $0.653($const0.654, $const0.655, func=$0.653, args=[Var($const0.654, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (51)), Var($const0.655, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (51))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.655
#     #   del $const0.654
#     #   del $0.653
#     #   $0.658 = $0.656 / Tgas  :: float64
#     #   del $0.656
#     #   $0.659 = call $0.652($0.658, func=$0.652, args=[Var($0.658, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (51))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.659
#     #   del $0.658
#     #   del $0.652
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 52 ---
#     #   $0.667 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.668 = const(int, -52536)  :: int64
#     #   $0.670 = $const0.668 / Tgas  :: float64
#     #   del $const0.668
# ...
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1013 ---
#     #   $0.21809 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21810 = const(int, -52536)  :: int64
#     #   $0.21812 = $const0.21810 / Tgas  :: float64
#     #   del $const0.21810
#     #   $0.21813 = call $0.21809($0.21812, func=$0.21809, args=[Var($0.21812, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1013))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21813
#     #   del $0.21812
#     #   del $0.21809
#     #   $0.21816 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21817 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21818 = const(int, 51994)  :: int64
#     #   $const0.21819 = const(float, 52534.079999999994)  :: float64
#     #   $0.21820 = call $0.21817($const0.21818, $const0.21819, func=$0.21817, args=[Var($const0.21818, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1013)), Var($const0.21819, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1013))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21819
#     #   del $const0.21818
#     #   del $0.21817
#     #   $0.21822 = $0.21820 / Tgas  :: float64
#     #   del $0.21820
#     #   $0.21823 = call $0.21816($0.21822, func=$0.21816, args=[Var($0.21822, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1013))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21823
#     #   del $0.21822
#     #   del $0.21816
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1014 ---
#     #   $0.21831 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21832 = const(int, -52536)  :: int64
#     #   $0.21834 = $const0.21832 / Tgas  :: float64
#     #   del $const0.21832
#     #   $0.21835 = call $0.21831($0.21834, func=$0.21831, args=[Var($0.21834, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1014))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21835
#     #   del $0.21834
#     #   del $0.21831
#     #   $0.21838 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21839 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21840 = const(int, 51994)  :: int64
#     #   $const0.21841 = const(float, 52534.079999999994)  :: float64
#     #   $0.21842 = call $0.21839($const0.21840, $const0.21841, func=$0.21839, args=[Var($const0.21840, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1014)), Var($const0.21841, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1014))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21841
#     #   del $const0.21840
#     #   del $0.21839
#     #   $0.21844 = $0.21842 / Tgas  :: float64
#     #   del $0.21842
#     #   $0.21845 = call $0.21838($0.21844, func=$0.21838, args=[Var($0.21844, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1014))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21845
#     #   del $0.21844
#     #   del $0.21838
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1015 ---
#     #   $0.21853 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21854 = const(int, -52536)  :: int64
#     #   $0.21856 = $const0.21854 / Tgas  :: float64
#     #   del $const0.21854
#     #   $0.21857 = call $0.21853($0.21856, func=$0.21853, args=[Var($0.21856, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1015))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21857
#     #   del $0.21856
#     #   del $0.21853
#     #   $0.21860 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21861 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21862 = const(int, 51994)  :: int64
#     #   $const0.21863 = const(float, 52534.079999999994)  :: float64
#     #   $0.21864 = call $0.21861($const0.21862, $const0.21863, func=$0.21861, args=[Var($const0.21862, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1015)), Var($const0.21863, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1015))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21863
#     #   del $const0.21862
#     #   del $0.21861
#     #   $0.21866 = $0.21864 / Tgas  :: float64
#     #   del $0.21864
#     #   $0.21867 = call $0.21860($0.21866, func=$0.21860, args=[Var($0.21866, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1015))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21867
#     #   del $0.21866
#     #   del $0.21860
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1016 ---
#     #   $0.21875 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21876 = const(int, -52536)  :: int64
#     #   $0.21878 = $const0.21876 / Tgas  :: float64
#     #   del $const0.21876
#     #   $0.21879 = call $0.21875($0.21878, func=$0.21875, args=[Var($0.21878, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1016))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21879
#     #   del $0.21878
#     #   del $0.21875
#     #   $0.21882 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21883 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21884 = const(int, 51994)  :: int64
#     #   $const0.21885 = const(float, 52534.079999999994)  :: float64
#     #   $0.21886 = call $0.21883($const0.21884, $const0.21885, func=$0.21883, args=[Var($const0.21884, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1016)), Var($const0.21885, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1016))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21885
#     #   del $const0.21884
#     #   del $0.21883
#     #   $0.21888 = $0.21886 / Tgas  :: float64
#     #   del $0.21886
#     #   $0.21889 = call $0.21882($0.21888, func=$0.21882, args=[Var($0.21888, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1016))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21889
#     #   del $0.21888
#     #   del $0.21882
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1017 ---
#     #   $0.21897 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21898 = const(int, -52536)  :: int64
#     #   $0.21900 = $const0.21898 / Tgas  :: float64
#     #   del $const0.21898
#     #   $0.21901 = call $0.21897($0.21900, func=$0.21897, args=[Var($0.21900, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1017))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21901
#     #   del $0.21900
#     #   del $0.21897
#     #   $0.21904 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21905 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21906 = const(int, 51994)  :: int64
#     #   $const0.21907 = const(float, 52534.079999999994)  :: float64
#     #   $0.21908 = call $0.21905($const0.21906, $const0.21907, func=$0.21905, args=[Var($const0.21906, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1017)), Var($const0.21907, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1017))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21907
#     #   del $const0.21906
#     #   del $0.21905
#     #   $0.21910 = $0.21908 / Tgas  :: float64
#     #   del $0.21908
#     #   $0.21911 = call $0.21904($0.21910, func=$0.21904, args=[Var($0.21910, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1017))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21911
#     #   del $0.21910
#     #   del $0.21904
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1018 ---
#     #   $0.21919 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21920 = const(int, -52536)  :: int64
#     #   $0.21922 = $const0.21920 / Tgas  :: float64
#     #   del $const0.21920
#     #   $0.21923 = call $0.21919($0.21922, func=$0.21919, args=[Var($0.21922, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1018))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21923
#     #   del $0.21922
#     #   del $0.21919
#     #   $0.21926 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21927 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21928 = const(int, 51994)  :: int64
#     #   $const0.21929 = const(float, 52534.079999999994)  :: float64
#     #   $0.21930 = call $0.21927($const0.21928, $const0.21929, func=$0.21927, args=[Var($const0.21928, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1018)), Var($const0.21929, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1018))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21929
#     #   del $const0.21928
#     #   del $0.21927
#     #   $0.21932 = $0.21930 / Tgas  :: float64
#     #   del $0.21930
#     #   $0.21933 = call $0.21926($0.21932, func=$0.21926, args=[Var($0.21932, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1018))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21933
#     #   del $0.21932
#     #   del $0.21926
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1019 ---
#     #   $0.21941 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21942 = const(int, -52536)  :: int64
#     #   $0.21944 = $const0.21942 / Tgas  :: float64
#     #   del $const0.21942
#     #   $0.21945 = call $0.21941($0.21944, func=$0.21941, args=[Var($0.21944, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1019))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21945
#     #   del $0.21944
#     #   del $0.21941
#     #   $0.21948 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21949 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21950 = const(int, 51994)  :: int64
#     #   $const0.21951 = const(float, 52534.079999999994)  :: float64
#     #   $0.21952 = call $0.21949($const0.21950, $const0.21951, func=$0.21949, args=[Var($const0.21950, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1019)), Var($const0.21951, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1019))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21951
#     #   del $const0.21950
#     #   del $0.21949
#     #   $0.21954 = $0.21952 / Tgas  :: float64
#     #   del $0.21952
#     #   $0.21955 = call $0.21948($0.21954, func=$0.21948, args=[Var($0.21954, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1019))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21955
#     #   del $0.21954
#     #   del $0.21948
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1020 ---
#     #   $0.21963 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21964 = const(int, -52536)  :: int64
#     #   $0.21966 = $const0.21964 / Tgas  :: float64
#     #   del $const0.21964
#     #   $0.21967 = call $0.21963($0.21966, func=$0.21963, args=[Var($0.21966, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1020))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21967
#     #   del $0.21966
#     #   del $0.21963
#     #   $0.21970 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21971 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21972 = const(int, 51994)  :: int64
#     #   $const0.21973 = const(float, 52534.079999999994)  :: float64
#     #   $0.21974 = call $0.21971($const0.21972, $const0.21973, func=$0.21971, args=[Var($const0.21972, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1020)), Var($const0.21973, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1020))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21973
#     #   del $const0.21972
#     #   del $0.21971
#     #   $0.21976 = $0.21974 / Tgas  :: float64
#     #   del $0.21974
#     #   $0.21977 = call $0.21970($0.21976, func=$0.21970, args=[Var($0.21976, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1020))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21977
#     #   del $0.21976
#     #   del $0.21970
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1021 ---
#     #   $const0.21979 = const(float, 3.8)  :: float64
#     #   $const0.21980 = const(float, 7.6028e-11)  :: float64
#     #   $const0.21982 = const(float, -1.4)  :: float64
#     #   $0.21983 = Tgas ** $const0.21982  :: float64
#     #   del $const0.21982
#     #   $0.21984 = $const0.21980 * $0.21983  :: float64
#     #   del $const0.21980
#     #   del $0.21983
#     #   $0.21985 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $const0.21986 = const(int, -52536)  :: int64
#     #   $0.21988 = $const0.21986 / Tgas  :: float64
#     #   del $const0.21986
#     #   $0.21989 = call $0.21985($0.21988, func=$0.21985, args=[Var($0.21988, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1021))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21988
#     #   del $0.21985
#     #   $0.21990 = $0.21984 * $0.21989  :: float64
#     #   del $0.21989
#     #   del $0.21984
#     #   $0.21991 = $const0.21979 * $0.21990  :: float64
#     #   del $const0.21979
#     #   del $0.21990
#     #   $0.21992 = global(exp: <built-in function exp>)  :: Function(<built-in function exp>)
#     #   $0.21993 = global(min: <built-in function min>)  :: Function(<built-in function min>)
#     #   $const0.21994 = const(int, 51994)  :: int64
#     #   $const0.21995 = const(float, 52534.079999999994)  :: float64
#     #   $0.21996 = call $0.21993($const0.21994, $const0.21995, func=$0.21993, args=[Var($const0.21994, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1021)), Var($const0.21995, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1021))], kws=(), vararg=None)  :: (int64, float64) -> float64
#     #   del $const0.21995
#     #   del $const0.21994
#     #   del $0.21993
#     #   $0.21998 = $0.21996 / Tgas  :: float64
#     #   del Tgas
#     #   del $0.21996
#     #   $0.21999 = call $0.21992($0.21998, func=$0.21992, args=[Var($0.21998, C:\Users\LiuJinbao\Documents\Code\PlasmaChemistry\_cache\cache.py (1021))], kws=(), vararg=None)  :: (float64,) -> float64
#     #   del $0.21998
#     #   del $0.21992
#     #   $value.1000.17999 = $0.21991 * $0.21999  :: float64
#     #   del $0.21999
#     #   del $0.21991
#
#     value = (3.8)*((4.58e+19*1.66e-30)*Tgas**(-1.4)*exp(-52536/Tgas))*exp(min(51994*(1),(104400*0.5032))/Tgas)
#
#     # --- LINE 1022 ---
#     #   $0.22002 = cast(value=$value.1000.17999)  :: float64
#     #   del $value.1000.17999
#     #   return $0.22002
#
#     return value
#
#
# ================================================================================

# %%
a = np.zeros(_number)
cache.test(a, 3000.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ead8f92412a5> in <module>()
#       1 a = np.zeros(_number)
# ----> 2 cache.test(a, 3000.0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numba\dispatcher.py in _explain_matching_error(self, *args, **kws)
#     462         msg = ("No matching definition for argument type(s) %s"
#     463                % ', '.join(map(str, args)))
# --> 464         raise TypeError(msg)
#     465
#     466     def _search_new_conversions(self, *args, **kws):
#
# TypeError: No matching definition for argument type(s) array(float64, 1d, C), float64

# %%
print(f"{end-start:.1f} s")
# Out:
# 238.2 s

# %%
# %timeit cache.test(a, 3000)
# Out:
# 936 ns ± 32.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ![%E5%9B%BE%E7%89%87.png](attachment:%E5%9B%BE%E7%89%87.png)
# 8000 reactions
#
# (numpy)exec time   :   4.4 ms
#
# (numba)exec time   :   3.6 us
#
# 1000 higher speed
#
# compile time   : 179.5  s

# %%
min(3,2)
# Out:
# 2
