# %%
import re

# %%
rctn_regexp = re.compile(r"""
\s*Reaction.*\n
\s*Name.*\n
\s*Format\s*("CO2.*v1.*)\n""", re.VERBOSE|re.MULTILINE)

# %%
with open('_cs_list/koelman2016/models/CO2_chemistry.gum') as f:
    _line = f.readlines()
_line = ''.join(_line)

# %%
rctn_regexp.findall(_line)
# Out:
# ['"CO2[v10] -> CO + O"',
#  '"CO2[v11] -> CO + O"',
#  '"CO2[v12] -> CO + O"',
#  '"CO2[v13] -> CO + O"',
#  '"CO2[v14] -> CO + O"',
#  '"CO2[v15] -> CO + O"',
#  '"CO2[v16] -> CO + O"',
#  '"CO2[v17] -> CO + O"',
#  '"CO2[v18] -> CO + O"',
#  '"CO2[v19] -> CO + O"',
#  '"CO2[v10] + O -> CO + O2"',
#  '"CO2[v11] + O -> CO + O2"',
#  '"CO2[v12] + O -> CO + O2"',
#  '"CO2[v13] + O -> CO + O2"',
#  '"CO2[v14] + O -> CO + O2"',
#  '"CO2[v15] + O -> CO + O2"',
#  '"CO2[v16] + O -> CO + O2"',
#  '"CO2[v17] + O -> CO + O2"',
#  '"CO2[v18] + O -> CO + O2"',
#  '"CO2[v19] + O -> CO + O2"',
#  '"CO2[v10] + C -> CO + CO"',
#  '"CO2[v11] + C -> CO + CO"',
#  '"CO2[v12] + C -> CO + CO"',
#  '"CO2[v13] + C -> CO + CO"',
#  '"CO2[v14] + C -> CO + CO"',
#  '"CO2[v15] + C -> CO + CO"',
#  '"CO2[v16] + C -> CO + CO"',
#  '"CO2[v17] + C -> CO + CO"',
#  '"CO2[v18] + C -> CO + CO"',
#  '"CO2[v19] + C -> CO + CO"',
#  '"CO2+ + CO2[v10] -> C2O4+"',
#  '"CO2+ + CO2[v11] -> C2O4+"',
#  '"CO2+ + CO2[v12] -> C2O4+"',
#  '"CO2+ + CO2[v13] -> C2O4+"',
#  '"CO2+ + CO2[v14] -> C2O4+"',
#  '"CO2+ + CO2[v15] -> C2O4+"',
#  '"CO2+ + CO2[v16] -> C2O4+"',
#  '"CO2+ + CO2[v17] -> C2O4+"',
#  '"CO2+ + CO2[v18] -> C2O4+"',
#  '"CO2+ + CO2[v19] -> C2O4+"',
#  '"CO2[va] + CO2[v10] -> CO2 + CO2[v10]"',
#  '"CO2[va] + CO2[v11] -> CO2 + CO2[v11]"',
#  '"CO2[va] + CO2[v12] -> CO2 + CO2[v12]"',
#  '"CO2[va] + CO2[v13] -> CO2 + CO2[v13]"',
#  '"CO2[va] + CO2[v14] -> CO2 + CO2[v14]"',
#  '"CO2[va] + CO2[v15] -> CO2 + CO2[v15]"',
#  '"CO2[va] + CO2[v16] -> CO2 + CO2[v16]"',
#  '"CO2[va] + CO2[v17] -> CO2 + CO2[v17]"',
#  '"CO2[va] + CO2[v18] -> CO2 + CO2[v18]"',
#  '"CO2[va] + CO2[v19] -> CO2 + CO2[v19]"',
#  '"CO2[va] + CO[v10] -> CO2 + CO[v10]"',
#  '"CO2[vb] + CO2[v10] -> CO2[va] + CO2[v10]"',
#  '"CO2[vb] + CO2[v11] -> CO2[va] + CO2[v11]"',
#  '"CO2[vb] + CO2[v12] -> CO2[va] + CO2[v12]"',
#  '"CO2[vb] + CO2[v13] -> CO2[va] + CO2[v13]"',
#  '"CO2[vb] + CO2[v14] -> CO2[va] + CO2[v14]"',
#  '"CO2[vb] + CO2[v15] -> CO2[va] + CO2[v15]"',
#  '"CO2[vb] + CO2[v16] -> CO2[va] + CO2[v16]"',
#  '"CO2[vb] + CO2[v17] -> CO2[va] + CO2[v17]"',
#  '"CO2[vb] + CO2[v18] -> CO2[va] + CO2[v18]"',
#  '"CO2[vb] + CO2[v19] -> CO2[va] + CO2[v19]"',
#  '"CO2[vb] + CO[v10] -> CO2[va] + CO[v10]"',
#  '"CO2[vc] + CO2[v10] -> CO2[vb] + CO2[v10]"',
#  '"CO2[vc] + CO2[v11] -> CO2[vb] + CO2[v11]"',
#  '"CO2[vc] + CO2[v12] -> CO2[vb] + CO2[v12]"',
#  '"CO2[vc] + CO2[v13] -> CO2[vb] + CO2[v13]"',
#  '"CO2[vc] + CO2[v14] -> CO2[vb] + CO2[v14]"',
#  '"CO2[vc] + CO2[v15] -> CO2[vb] + CO2[v15]"',
#  '"CO2[vc] + CO2[v16] -> CO2[vb] + CO2[v16]"',
#  '"CO2[vc] + CO2[v17] -> CO2[vb] + CO2[v17]"',
#  '"CO2[vc] + CO2[v18] -> CO2[vb] + CO2[v18]"',
#  '"CO2[vc] + CO2[v19] -> CO2[vb] + CO2[v19]"',
#  '"CO2[vc] + CO[v10] -> CO2[vb] + CO[v10]"',
#  '"CO2[vd] + CO2[v10] -> CO2[vc] + CO2[v10]"',
#  '"CO2[vd] + CO2[v11] -> CO2[vc] + CO2[v11]"',
#  '"CO2[vd] + CO2[v12] -> CO2[vc] + CO2[v12]"',
#  '"CO2[vd] + CO2[v13] -> CO2[vc] + CO2[v13]"',
#  '"CO2[vd] + CO2[v14] -> CO2[vc] + CO2[v14]"',
#  '"CO2[vd] + CO2[v15] -> CO2[vc] + CO2[v15]"',
#  '"CO2[vd] + CO2[v16] -> CO2[vc] + CO2[v16]"',
#  '"CO2[vd] + CO2[v17] -> CO2[vc] + CO2[v17]"',
#  '"CO2[vd] + CO2[v18] -> CO2[vc] + CO2[v18]"',
#  '"CO2[vd] + CO2[v19] -> CO2[vc] + CO2[v19]"',
#  '"CO2[vd] + CO[v10] -> CO2[vc] + CO[v10]"',
#  '"CO2[v01] + CO2[v10] -> CO2[va] + CO2[v10]"',
#  '"CO2[v01] + CO2[v10] -> CO2[vb] + CO2[v10]"',
#  '"CO2[v01] + CO2[v10] -> CO2[vc] + CO2[v10]"',
#  '"CO2[v01] + CO2[v11] -> CO2[va] + CO2[v11]"',
#  '"CO2[v01] + CO2[v11] -> CO2[vb] + CO2[v11]"',
#  '"CO2[v01] + CO2[v11] -> CO2[vc] + CO2[v11]"',
#  '"CO2[v01] + CO2[v12] -> CO2[va] + CO2[v12]"',
#  '"CO2[v01] + CO2[v12] -> CO2[vb] + CO2[v12]"',
#  '"CO2[v01] + CO2[v12] -> CO2[vc] + CO2[v12]"',
#  '"CO2[v01] + CO2[v13] -> CO2[va] + CO2[v13]"',
#  '"CO2[v01] + CO2[v13] -> CO2[vb] + CO2[v13]"',
#  '"CO2[v01] + CO2[v13] -> CO2[vc] + CO2[v13]"',
#  '"CO2[v01] + CO2[v14] -> CO2[va] + CO2[v14]"',
#  '"CO2[v01] + CO2[v14] -> CO2[vb] + CO2[v14]"',
#  '"CO2[v01] + CO2[v14] -> CO2[vc] + CO2[v14]"',
#  '"CO2[v01] + CO2[v15] -> CO2[va] + CO2[v15]"',
#  '"CO2[v01] + CO2[v15] -> CO2[vb] + CO2[v15]"',
#  '"CO2[v01] + CO2[v15] -> CO2[vc] + CO2[v15]"',
#  '"CO2[v01] + CO2[v16] -> CO2[va] + CO2[v16]"',
#  '"CO2[v01] + CO2[v16] -> CO2[vb] + CO2[v16]"',
#  '"CO2[v01] + CO2[v16] -> CO2[vc] + CO2[v16]"',
#  '"CO2[v01] + CO2[v17] -> CO2[va] + CO2[v17]"',
#  '"CO2[v01] + CO2[v17] -> CO2[vb] + CO2[v17]"',
#  '"CO2[v01] + CO2[v17] -> CO2[vc] + CO2[v17]"',
#  '"CO2[v01] + CO2[v18] -> CO2[va] + CO2[v18]"',
#  '"CO2[v01] + CO2[v18] -> CO2[vb] + CO2[v18]"',
#  '"CO2[v01] + CO2[v18] -> CO2[vc] + CO2[v18]"',
#  '"CO2[v01] + CO2[v19] -> CO2[va] + CO2[v19]"',
#  '"CO2[v01] + CO2[v19] -> CO2[vb] + CO2[v19]"',
#  '"CO2[v01] + CO2[v19] -> CO2[vc] + CO2[v19]"',
#  '"CO2[v01] + CO[v10] -> CO2[va] + CO[v10]"',
#  '"CO2[v01] + CO[v10] -> CO2[vb] + CO[v10]"',
#  '"CO2[v01] + CO[v10] -> CO2[vc] + CO[v10]"',
#  '"CO2[v02] + CO2[v10] -> CO2[v01] + CO2[v10]"',
#  '"CO2[v02] + CO2[v11] -> CO2[v01] + CO2[v11]"',
#  '"CO2[v02] + CO2[v12] -> CO2[v01] + CO2[v12]"',
#  '"CO2[v02] + CO2[v13] -> CO2[v01] + CO2[v13]"',
#  '"CO2[v02] + CO2[v14] -> CO2[v01] + CO2[v14]"',
#  '"CO2[v02] + CO2[v15] -> CO2[v01] + CO2[v15]"',
#  '"CO2[v02] + CO2[v16] -> CO2[v01] + CO2[v16]"',
#  '"CO2[v02] + CO2[v17] -> CO2[v01] + CO2[v17]"',
#  '"CO2[v02] + CO2[v18] -> CO2[v01] + CO2[v18]"',
#  '"CO2[v02] + CO2[v19] -> CO2[v01] + CO2[v19]"',
#  '"CO2[v02] + CO[v10] -> CO2[v01] + CO[v10]"',
#  '"CO2[v03] + CO2[v10] -> CO2[v02] + CO2[v10]"',
#  '"CO2[v03] + CO2[v11] -> CO2[v02] + CO2[v11]"',
#  '"CO2[v03] + CO2[v12] -> CO2[v02] + CO2[v12]"',
#  '"CO2[v03] + CO2[v13] -> CO2[v02] + CO2[v13]"',
#  '"CO2[v03] + CO2[v14] -> CO2[v02] + CO2[v14]"',
#  '"CO2[v03] + CO2[v15] -> CO2[v02] + CO2[v15]"',
#  '"CO2[v03] + CO2[v16] -> CO2[v02] + CO2[v16]"',
#  '"CO2[v03] + CO2[v17] -> CO2[v02] + CO2[v17]"',
#  '"CO2[v03] + CO2[v18] -> CO2[v02] + CO2[v18]"',
#  '"CO2[v03] + CO2[v19] -> CO2[v02] + CO2[v19]"',
#  '"CO2[v03] + CO[v10] -> CO2[v02] + CO[v10]"',
#  '"CO2[v04] + CO2[v10] -> CO2[v03] + CO2[v10]"',
#  '"CO2[v04] + CO2[v11] -> CO2[v03] + CO2[v11]"',
#  '"CO2[v04] + CO2[v12] -> CO2[v03] + CO2[v12]"',
#  '"CO2[v04] + CO2[v13] -> CO2[v03] + CO2[v13]"',
#  '"CO2[v04] + CO2[v14] -> CO2[v03] + CO2[v14]"',
#  '"CO2[v04] + CO2[v15] -> CO2[v03] + CO2[v15]"',
#  '"CO2[v04] + CO2[v16] -> CO2[v03] + CO2[v16]"',
#  '"CO2[v04] + CO2[v17] -> CO2[v03] + CO2[v17]"',
#  '"CO2[v04] + CO2[v18] -> CO2[v03] + CO2[v18]"',
#  '"CO2[v04] + CO2[v19] -> CO2[v03] + CO2[v19]"',
#  '"CO2[v04] + CO[v10] -> CO2[v03] + CO[v10]"',
#  '"CO2[v05] + CO2[v10] -> CO2[v04] + CO2[v10]"',
#  '"CO2[v05] + CO2[v11] -> CO2[v04] + CO2[v11]"',
#  '"CO2[v05] + CO2[v12] -> CO2[v04] + CO2[v12]"',
#  '"CO2[v05] + CO2[v13] -> CO2[v04] + CO2[v13]"',
#  '"CO2[v05] + CO2[v14] -> CO2[v04] + CO2[v14]"',
#  '"CO2[v05] + CO2[v15] -> CO2[v04] + CO2[v15]"',
#  '"CO2[v05] + CO2[v16] -> CO2[v04] + CO2[v16]"',
#  '"CO2[v05] + CO2[v17] -> CO2[v04] + CO2[v17]"',
#  '"CO2[v05] + CO2[v18] -> CO2[v04] + CO2[v18]"',
#  '"CO2[v05] + CO2[v19] -> CO2[v04] + CO2[v19]"',
#  '"CO2[v05] + CO[v10] -> CO2[v04] + CO[v10]"',
#  '"CO2[v06] + CO2[v10] -> CO2[v05] + CO2[v10]"',
#  '"CO2[v06] + CO2[v11] -> CO2[v05] + CO2[v11]"',
#  '"CO2[v06] + CO2[v12] -> CO2[v05] + CO2[v12]"',
#  '"CO2[v06] + CO2[v13] -> CO2[v05] + CO2[v13]"',
#  '"CO2[v06] + CO2[v14] -> CO2[v05] + CO2[v14]"',
#  '"CO2[v06] + CO2[v15] -> CO2[v05] + CO2[v15]"',
#  '"CO2[v06] + CO2[v16] -> CO2[v05] + CO2[v16]"',
#  '"CO2[v06] + CO2[v17] -> CO2[v05] + CO2[v17]"',
#  '"CO2[v06] + CO2[v18] -> CO2[v05] + CO2[v18]"',
#  '"CO2[v06] + CO2[v19] -> CO2[v05] + CO2[v19]"',
#  '"CO2[v06] + CO[v10] -> CO2[v05] + CO[v10]"',
#  '"CO2[v07] + CO2[v10] -> CO2[v06] + CO2[v10]"',
#  '"CO2[v07] + CO2[v11] -> CO2[v06] + CO2[v11]"',
#  '"CO2[v07] + CO2[v12] -> CO2[v06] + CO2[v12]"',
#  '"CO2[v07] + CO2[v13] -> CO2[v06] + CO2[v13]"',
#  '"CO2[v07] + CO2[v14] -> CO2[v06] + CO2[v14]"',
#  '"CO2[v07] + CO2[v15] -> CO2[v06] + CO2[v15]"',
#  '"CO2[v07] + CO2[v16] -> CO2[v06] + CO2[v16]"',
#  '"CO2[v07] + CO2[v17] -> CO2[v06] + CO2[v17]"',
#  '"CO2[v07] + CO2[v18] -> CO2[v06] + CO2[v18]"',
#  '"CO2[v07] + CO2[v19] -> CO2[v06] + CO2[v19]"',
#  '"CO2[v07] + CO[v10] -> CO2[v06] + CO[v10]"',
#  '"CO2[v08] + CO2[v10] -> CO2[v07] + CO2[v10]"',
#  '"CO2[v08] + CO2[v11] -> CO2[v07] + CO2[v11]"',
#  '"CO2[v08] + CO2[v12] -> CO2[v07] + CO2[v12]"',
#  '"CO2[v08] + CO2[v13] -> CO2[v07] + CO2[v13]"',
#  '"CO2[v08] + CO2[v14] -> CO2[v07] + CO2[v14]"',
#  '"CO2[v08] + CO2[v15] -> CO2[v07] + CO2[v15]"',
#  '"CO2[v08] + CO2[v16] -> CO2[v07] + CO2[v16]"',
#  '"CO2[v08] + CO2[v17] -> CO2[v07] + CO2[v17]"',
#  '"CO2[v08] + CO2[v18] -> CO2[v07] + CO2[v18]"',
#  '"CO2[v08] + CO2[v19] -> CO2[v07] + CO2[v19]"',
#  '"CO2[v08] + CO[v10] -> CO2[v07] + CO[v10]"',
#  '"CO2[v09] + CO2[v10] -> CO2[v08] + CO2[v10]"',
#  '"CO2[v09] + CO2[v11] -> CO2[v08] + CO2[v11]"',
#  '"CO2[v09] + CO2[v12] -> CO2[v08] + CO2[v12]"',
#  '"CO2[v09] + CO2[v13] -> CO2[v08] + CO2[v13]"',
#  '"CO2[v09] + CO2[v14] -> CO2[v08] + CO2[v14]"',
#  '"CO2[v09] + CO2[v15] -> CO2[v08] + CO2[v15]"',
#  '"CO2[v09] + CO2[v16] -> CO2[v08] + CO2[v16]"',
#  '"CO2[v09] + CO2[v17] -> CO2[v08] + CO2[v17]"',
#  '"CO2[v09] + CO2[v18] -> CO2[v08] + CO2[v18]"',
#  '"CO2[v09] + CO2[v19] -> CO2[v08] + CO2[v19]"',
#  '"CO2[v09] + CO[v10] -> CO2[v08] + CO[v10]"',
#  '"CO2[v10] + CO2 -> CO2[v09] + CO2"',
#  '"CO2[v10] + CO2[v01] -> CO2[v09] + CO2[v01]"',
#  '"CO2[v10] + CO2[v02] -> CO2[v09] + CO2[v02]"',
#  '"CO2[v10] + CO2[v03] -> CO2[v09] + CO2[v03]"',
#  '"CO2[v10] + CO2[v04] -> CO2[v09] + CO2[v04]"',
#  '"CO2[v10] + CO2[v05] -> CO2[v09] + CO2[v05]"',
#  '"CO2[v10] + CO2[v06] -> CO2[v09] + CO2[v06]"',
#  '"CO2[v10] + CO2[v07] -> CO2[v09] + CO2[v07]"',
#  '"CO2[v10] + CO2[v08] -> CO2[v09] + CO2[v08]"',
#  '"CO2[v10] + CO2[v09] -> CO2[v09] + CO2[v09]"',
#  '"CO2[v10] + CO2[v10] -> CO2[v09] + CO2[v10]"',
#  '"CO2[v10] + CO2[v11] -> CO2[v09] + CO2[v11]"',
#  '"CO2[v10] + CO2[v12] -> CO2[v09] + CO2[v12]"',
#  '"CO2[v10] + CO2[v13] -> CO2[v09] + CO2[v13]"',
#  '"CO2[v10] + CO2[v14] -> CO2[v09] + CO2[v14]"',
#  '"CO2[v10] + CO2[v15] -> CO2[v09] + CO2[v15]"',
#  '"CO2[v10] + CO2[v16] -> CO2[v09] + CO2[v16]"',
#  '"CO2[v10] + CO2[v17] -> CO2[v09] + CO2[v17]"',
#  '"CO2[v10] + CO2[v18] -> CO2[v09] + CO2[v18]"',
#  '"CO2[v10] + CO2[v19] -> CO2
# <b>limit_output extension: Maximum message size of 10000 exceeded with 43425 characters</b>
